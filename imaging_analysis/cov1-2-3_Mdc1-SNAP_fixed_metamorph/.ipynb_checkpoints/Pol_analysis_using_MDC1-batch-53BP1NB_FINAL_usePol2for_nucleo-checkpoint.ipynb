# %% [markdown]
# # Import required modules

# %%
import numpy as np
import matplotlib.pyplot as plt
from skimage import io
from skimage import data
import skimage
from skimage.filters.thresholding import threshold_li
from skimage.morphology import erosion, dilation, opening, closing, white_tophat, remove_small_objects
from skimage.morphology import disk
from scipy import ndimage as ndi
import sys,os, glob

#import skimage.segmentation as seg
#import skimage.filters as filters
#import skimage.draw as draw
#import skimage.color as color

#from skimage.filters.thresholding import _cross_entropy
#from skimage.morphology import black_tophat, skeletonize, convex_hull_image
# Out:
# c:\programdata\anaconda3\lib\site-packages\skimage\io\manage_plugins.py:23: UserWarning: Your installed pillow version is < 7.1.0. Several security issues (CVE-2020-11538, CVE-2020-10379, CVE-2020-10994, CVE-2020-10177) have been fixed in pillow 7.1.0 or higher. We recommend to upgrade this library.
#   from .collection import imread_collection_wrapper

# %% [markdown]
# # Define parameters for image loading here:

# %%
# Common parameters for loading the image files of interest

# for 4 channels metamorph images: channel index order is 1-2-3-4, which is the order as ch405-ch488-ch560-ch647

num_of_ch = 4

# Replace protein/dna label name in the "xxx" below for the indicated channel index (make sure the order is correct)
# For example: ch_dict = {"dna":1,"rpa/rpa2":2,"mdc1":3,"pol2S5":4} if rpa/rpa2 was used for ch488
# Make sure the label name is the same as the factor/dna key used in the line below
ch_dict = {"dna":1,"53BP1NB":2,"mdc1":3,"pol2S5":4}

# If use mdc1 as the factor for region segementation
# If use dna/dapi as the key channel for nucleus segmentation
factor_key =  "mdc1"
dna_key = "dna"

pol2_key = "pol2S5"

# Replace the data directory in the ""; * is the final path level where images are located
# For example: data_save_folder = r"F:\XXX\AAA\BBB\*"
data_save_folder = r"E:\Data_Stam\210228IF_210225exp_Mdc1_Fixed\cov2_53BP1NB\*"

# %% [markdown]
# #  Load all image files

# %%
# read data files from the hard drive
data_folder = data_save_folder
data_files = [file for file in glob.glob(data_folder) if file[-3:]=="TIF" and "thumb" not in file]

# group images for the same fov
sorted_data_files = []
num_of_ch = num_of_ch
num_of_img = len(data_files)
if num_of_img%num_of_ch == 0: #check if all images contain the same number of channels
    for i in range (int(num_of_img/num_of_ch)):
        data_for_each_cell = data_files[i*num_of_ch:i*num_of_ch+4]
        sorted_data_files.append(data_for_each_cell)
        
num_of_fov =len(sorted_data_files)
print (f"There are {num_of_fov} fovs for this {num_of_ch}-channel image dataset.")
# Out:
# There are 25 fovs for this 4-channel image dataset.

# %% [markdown]
# # Load fov of interest to check images and peform nucleus segmentation

# %%
# The pixel size for excluding small 53BP_foci;
# Replace *300* with other number desired or *0* if do not want to perform 53BP1 foci exclusion
#small_53BP_size = 300

small_53BP_size = 0

# %%
# Generate an empty list to store all measurements
measurement_for_all_fov = []

#To analyze a subset of fovs, use the code below where *2* means fov_0-fov_1; to analyze all fovs, replace *2* with num_of_fov;
# the number needs to be <= num_of_fov

for _fov_id in range (num_of_fov):
        
    # load images for 4 channels for each fov
    img_1 = io.imread(sorted_data_files[_fov_id][0])  #ch405 
    img_2 = io.imread(sorted_data_files[_fov_id][1])  #ch488
    img_3 = io.imread(sorted_data_files[_fov_id][2])  #ch560
    img_4 = io.imread(sorted_data_files[_fov_id][3])  #ch642
    # Store images into an img_dict based on their channel index
    ch_img_dict={'1':img_1,'2':img_2,'3':img_3,'4':img_4}
    # Find the best focal plane using the mdc1 channel
    image_fl = []
    image_std = []
    for i in range(len(ch_img_dict[str(ch_dict[factor_key])])):
        _fl = np.array(ch_img_dict[str(ch_dict[factor_key])][i,:,:].flatten())
        image_fl.append(_fl)
        image_std.append(np.std(_fl))
    best_plane_index = np.argmax(np.array(image_std))
    print(f"Analyzing the plane {best_plane_index} for the image {_fov_id} in this dataset")   
    
    # load the best focal plane
    img_1_bf=img_1[best_plane_index,:,:]
    img_2_bf=img_2[best_plane_index,:,:]
    img_3_bf=img_3[best_plane_index,:,:]
    img_4_bf=img_4[best_plane_index,:,:]
    # Update the img_dict
    ch_img_dict={'1':img_1_bf,'2':img_2_bf,'3':img_3_bf,'4':img_4_bf}
    
    
    # Use Li_global_th and binary operations on the dna channel to generate nuclei masks
    li_value =  threshold_li (ch_img_dict[str(ch_dict[dna_key])])
    nuclei_mask = ch_img_dict[str(ch_dict[dna_key])]>li_value
    erosion_factor_dna = 5
    eroded_nuclei_mask = erosion(nuclei_mask, disk(erosion_factor_dna))
    eroded_nuclei_mask = ndi.binary_fill_holes(eroded_nuclei_mask)
    eroded_nuclei_mask = remove_small_objects(eroded_nuclei_mask, 10000,connectivity=1)

    # erosion and dilation to remove micronuclei or small blebs
    eroded_nuclei_mask = erosion(eroded_nuclei_mask, disk(25))
    eroded_nuclei_mask = dilation(eroded_nuclei_mask, disk(25))
    # Nuclei segmentation to get all valid nuclei of interest
    labeled_nuclei, num_of_nuclei = ndi.label(eroded_nuclei_mask)

    # Add all valid nuclei to the list for downstream analysis
    kept_nuclei = []
    for i in range(num_of_nuclei):
        cand_nucleus = labeled_nuclei == i+1
        cand_nucleus[cand_nucleus>0]=1
        cand_nucleus = np.array(cand_nucleus)
        kept_nuclei.append(cand_nucleus)
       
    # Analyze each cell from this fov for all channels
    for cell_id in range(len(kept_nuclei)):
        # Generate masks for the MDC-labeled chromosome ("the reincorporated micronuclei") on the mdc1 channel
        # Q3 + 3* IQR (mdc1 intensity for the analyzed nucleus) used as the threshold for its segmentation
        nuclei_to_measure = kept_nuclei[cell_id]
        mdc_intensity = ch_img_dict[str(ch_dict[factor_key])]*nuclei_to_measure
        mdc_intensity_filtered = np.array([i for i in mdc_intensity.flatten() if i >0])
        mdc_iqr = (np.percentile(mdc_intensity_filtered,75)-np.percentile(mdc_intensity_filtered,25))
        mdc_positive_th = np.percentile(mdc_intensity_filtered,75) + mdc_iqr*3
        mdc_chr_mask = (ch_img_dict[str(ch_dict[factor_key])]>mdc_positive_th)*nuclei_to_measure
        
        # Removing small potential 53BP foci (change pixel size in the box above)
        mdc_chr_mask = remove_small_objects(mdc_chr_mask, small_53BP_size, connectivity=1)
        
        # Remove tiny unsure foci if no 53BP foci size exclusion were applied
        if small_53BP_size == 0:
            small_53BP_size = 100
        else:
            pass
        
        # Analyze valid mdc-labeled nuclear regions only
        if sum(mdc_chr_mask.flatten())>small_53BP_size:
            
            # Generate mask for the MDC-negative nucleous
            # lower 10% of the mdc1 intensity for the analyzed nucleus used to define the nucleolus 
            dna_intensity = ch_img_dict[str(ch_dict[dna_key])]*nuclei_to_measure
            dna_intensity_filtered = np.array([i for i in dna_intensity.flatten() if i >0])
            dna_negative_th = np.percentile(dna_intensity_filtered,10)
            mdc_negative_th = np.percentile(mdc_intensity_filtered,10)
            
            pol2_intensity_filtered = ch_img_dict[str(ch_dict[dna_key])]*nuclei_to_measure
            pol2_negative_th = np.percentile(pol2_intensity_filtered,10)
            
            
            dna_negative_mask = (ch_img_dict[str(ch_dict[dna_key])]<dna_negative_th)*nuclei_to_measure
            mdc_negative_mask = (ch_img_dict[str(ch_dict[factor_key])]<mdc_negative_th)*nuclei_to_measure         
            nucleolus_mask = dilation(mdc_negative_mask, disk(2))
            
            
            # Generate mask for the rest chr in nuclei by removing the mdc-labeled and nucleolus regions
            ctrl_chr_mask1 = nuclei_to_measure *  (mdc_chr_mask == 0)
            ctrl_chr_mask2 = nuclei_to_measure * (nucleolus_mask ==0)
            ctrl_chr_mask = ctrl_chr_mask1*ctrl_chr_mask2
            # Generate mask for the non-cell/non-nuclei background
            noncell_background = erosion(nuclei_mask==0,disk(10))
            
            
            # Save mask images in the source directory
            mask_save_path = data_save_folder[:-2] + os.sep + f'segmentations_{small_53BP_size}' + os.sep + f'fov_{_fov_id}'
            if not os.path.exists(mask_save_path):
                os.makedirs(mask_save_path)
            mdc_chr_mask_savename = f'cell_{cell_id}_incoporated_chr.tif'
            ctrl_chr_mask_savename = f'cell_{cell_id}_control_chr_cell.tif'
            io.imsave(mask_save_path+os.sep+mdc_chr_mask_savename,(mdc_chr_mask))
            io.imsave(mask_save_path+os.sep+ctrl_chr_mask_savename,(ctrl_chr_mask))
            
            
            # Generate an empty list to store measurement for each cells
            measurement_for_each_cell = []
            # Add fov_id and cell_id 
            measurement_for_each_cell.append (int(_fov_id))
            measurement_for_each_cell.append (int(cell_id))
            # Measure and add pixel area for MDC-labeled chromosome, control chromosomes, and nucleolus
            measurement_for_each_cell.append (int(sum(mdc_chr_mask.flatten())))
            measurement_for_each_cell.append (int(sum(ctrl_chr_mask.flatten())))
            measurement_for_each_cell.append (int(sum(nucleolus_mask.flatten())))
            
            # Measure and add intensity for MDC-labeled chromosome, control chromosomes, and nucleolus for each channel
            for ch in range(num_of_ch):
                ch_to_measure = ch_img_dict[str(ch+1)]
                # Measure ave intensity
                mdc_chr_ave_intensity = (ch_to_measure * mdc_chr_mask)[(ch_to_measure * mdc_chr_mask)!=0].mean()
                ctrl_chr_ave_intensity = (ch_to_measure * ctrl_chr_mask)[(ch_to_measure * ctrl_chr_mask)!=0].mean()
                nucleolus_ave_intensity = (ch_to_measure * nucleolus_mask)[(ch_to_measure * nucleolus_mask)!=0].mean()
                noncell_background_ave_intensity = (ch_to_measure*noncell_background)[(ch_to_measure*noncell_background)!=0].mean()
                # Background subtraction
                mdc_chr_ave_intensity = mdc_chr_ave_intensity - noncell_background_ave_intensity
                ctrl_chr_ave_intensity = ctrl_chr_ave_intensity - noncell_background_ave_intensity
                nucleolus_ave_intensity = nucleolus_ave_intensity - noncell_background_ave_intensity
                # Add measurements
                measurement_for_each_cell.append(mdc_chr_ave_intensity)
                measurement_for_each_cell.append(ctrl_chr_ave_intensity)
                measurement_for_each_cell.append(nucleolus_ave_intensity)
                        
            # Add measurements for each cell to the measurements for all fovs
            measurement_for_each_cell = np.array(measurement_for_each_cell)
            measurement_for_all_fov.append(measurement_for_each_cell)
# Out:
# Analyzing the plane 4 for the image 0 in this dataset
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:105: UserWarning: E:\Data_Stam\210228IF_210225exp_Mdc1_Fixed\cov2_53BP1NB\segmentations_100\fov_0\cell_2_incoporated_chr.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:105: UserWarning: E:\Data_Stam\210228IF_210225exp_Mdc1_Fixed\cov2_53BP1NB\segmentations_100\fov_0\cell_2_incoporated_chr.tif is a low contrast image
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:106: UserWarning: E:\Data_Stam\210228IF_210225exp_Mdc1_Fixed\cov2_53BP1NB\segmentations_100\fov_0\cell_2_control_chr_cell.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# Analyzing the plane 1 for the image 1 in this dataset
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:105: UserWarning: E:\Data_Stam\210228IF_210225exp_Mdc1_Fixed\cov2_53BP1NB\segmentations_100\fov_1\cell_1_incoporated_chr.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:105: UserWarning: E:\Data_Stam\210228IF_210225exp_Mdc1_Fixed\cov2_53BP1NB\segmentations_100\fov_1\cell_1_incoporated_chr.tif is a low contrast image
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:106: UserWarning: E:\Data_Stam\210228IF_210225exp_Mdc1_Fixed\cov2_53BP1NB\segmentations_100\fov_1\cell_1_control_chr_cell.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:105: UserWarning: E:\Data_Stam\210228IF_210225exp_Mdc1_Fixed\cov2_53BP1NB\segmentations_100\fov_1\cell_2_incoporated_chr.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:105: UserWarning: E:\Data_Stam\210228IF_210225exp_Mdc1_Fixed\cov2_53BP1NB\segmentations_100\fov_1\cell_2_incoporated_chr.tif is a low contrast image
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:106: UserWarning: E:\Data_Stam\210228IF_210225exp_Mdc1_Fixed\cov2_53BP1NB\segmentations_100\fov_1\cell_2_control_chr_cell.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# Analyzing the plane 3 for the image 2 in this dataset
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:105: UserWarning: E:\Data_Stam\210228IF_210225exp_Mdc1_Fixed\cov2_53BP1NB\segmentations_100\fov_2\cell_1_incoporated_chr.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:105: UserWarning: E:\Data_Stam\210228IF_210225exp_Mdc1_Fixed\cov2_53BP1NB\segmentations_100\fov_2\cell_1_incoporated_chr.tif is a low contrast image
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:106: UserWarning: E:\Data_Stam\210228IF_210225exp_Mdc1_Fixed\cov2_53BP1NB\segmentations_100\fov_2\cell_1_control_chr_cell.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# Analyzing the plane 4 for the image 3 in this dataset
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:105: UserWarning: E:\Data_Stam\210228IF_210225exp_Mdc1_Fixed\cov2_53BP1NB\segmentations_100\fov_3\cell_2_incoporated_chr.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:105: UserWarning: E:\Data_Stam\210228IF_210225exp_Mdc1_Fixed\cov2_53BP1NB\segmentations_100\fov_3\cell_2_incoporated_chr.tif is a low contrast image
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:106: UserWarning: E:\Data_Stam\210228IF_210225exp_Mdc1_Fixed\cov2_53BP1NB\segmentations_100\fov_3\cell_2_control_chr_cell.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# Analyzing the plane 2 for the image 4 in this dataset
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:105: UserWarning: E:\Data_Stam\210228IF_210225exp_Mdc1_Fixed\cov2_53BP1NB\segmentations_100\fov_4\cell_0_incoporated_chr.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:105: UserWarning: E:\Data_Stam\210228IF_210225exp_Mdc1_Fixed\cov2_53BP1NB\segmentations_100\fov_4\cell_0_incoporated_chr.tif is a low contrast image
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:106: UserWarning: E:\Data_Stam\210228IF_210225exp_Mdc1_Fixed\cov2_53BP1NB\segmentations_100\fov_4\cell_0_control_chr_cell.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:106: UserWarning: E:\Data_Stam\210228IF_210225exp_Mdc1_Fixed\cov2_53BP1NB\segmentations_100\fov_4\cell_0_control_chr_cell.tif is a low contrast image
# Analyzing the plane 1 for the image 5 in this dataset
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:105: UserWarning: E:\Data_Stam\210228IF_210225exp_Mdc1_Fixed\cov2_53BP1NB\segmentations_100\fov_5\cell_0_incoporated_chr.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:105: UserWarning: E:\Data_Stam\210228IF_210225exp_Mdc1_Fixed\cov2_53BP1NB\segmentations_100\fov_5\cell_0_incoporated_chr.tif is a low contrast image
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:106: UserWarning: E:\Data_Stam\210228IF_210225exp_Mdc1_Fixed\cov2_53BP1NB\segmentations_100\fov_5\cell_0_control_chr_cell.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:105: UserWarning: E:\Data_Stam\210228IF_210225exp_Mdc1_Fixed\cov2_53BP1NB\segmentations_100\fov_5\cell_2_incoporated_chr.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:105: UserWarning: E:\Data_Stam\210228IF_210225exp_Mdc1_Fixed\cov2_53BP1NB\segmentations_100\fov_5\cell_2_incoporated_chr.tif is a low contrast image
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:106: UserWarning: E:\Data_Stam\210228IF_210225exp_Mdc1_Fixed\cov2_53BP1NB\segmentations_100\fov_5\cell_2_control_chr_cell.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:105: UserWarning: E:\Data_Stam\210228IF_210225exp_Mdc1_Fixed\cov2_53BP1NB\segmentations_100\fov_5\cell_3_incoporated_chr.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:105: UserWarning: E:\Data_Stam\210228IF_210225exp_Mdc1_Fixed\cov2_53BP1NB\segmentations_100\fov_5\cell_3_incoporated_chr.tif is a low contrast image
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:106: UserWarning: E:\Data_Stam\210228IF_210225exp_Mdc1_Fixed\cov2_53BP1NB\segmentations_100\fov_5\cell_3_control_chr_cell.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# Analyzing the plane 3 for the image 6 in this dataset
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:105: UserWarning: E:\Data_Stam\210228IF_210225exp_Mdc1_Fixed\cov2_53BP1NB\segmentations_100\fov_6\cell_0_incoporated_chr.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:105: UserWarning: E:\Data_Stam\210228IF_210225exp_Mdc1_Fixed\cov2_53BP1NB\segmentations_100\fov_6\cell_0_incoporated_chr.tif is a low contrast image
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:106: UserWarning: E:\Data_Stam\210228IF_210225exp_Mdc1_Fixed\cov2_53BP1NB\segmentations_100\fov_6\cell_0_control_chr_cell.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:105: UserWarning: E:\Data_Stam\210228IF_210225exp_Mdc1_Fixed\cov2_53BP1NB\segmentations_100\fov_6\cell_1_incoporated_chr.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:105: UserWarning: E:\Data_Stam\210228IF_210225exp_Mdc1_Fixed\cov2_53BP1NB\segmentations_100\fov_6\cell_1_incoporated_chr.tif is a low contrast image
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:106: UserWarning: E:\Data_Stam\210228IF_210225exp_Mdc1_Fixed\cov2_53BP1NB\segmentations_100\fov_6\cell_1_control_chr_cell.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# Analyzing the plane 2 for the image 7 in this dataset
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:105: UserWarning: E:\Data_Stam\210228IF_210225exp_Mdc1_Fixed\cov2_53BP1NB\segmentations_100\fov_7\cell_1_incoporated_chr.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:105: UserWarning: E:\Data_Stam\210228IF_210225exp_Mdc1_Fixed\cov2_53BP1NB\segmentations_100\fov_7\cell_1_incoporated_chr.tif is a low contrast image
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:106: UserWarning: E:\Data_Stam\210228IF_210225exp_Mdc1_Fixed\cov2_53BP1NB\segmentations_100\fov_7\cell_1_control_chr_cell.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:105: UserWarning: E:\Data_Stam\210228IF_210225exp_Mdc1_Fixed\cov2_53BP1NB\segmentations_100\fov_7\cell_2_incoporated_chr.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:105: UserWarning: E:\Data_Stam\210228IF_210225exp_Mdc1_Fixed\cov2_53BP1NB\segmentations_100\fov_7\cell_2_incoporated_chr.tif is a low contrast image
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:106: UserWarning: E:\Data_Stam\210228IF_210225exp_Mdc1_Fixed\cov2_53BP1NB\segmentations_100\fov_7\cell_2_control_chr_cell.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:105: UserWarning: E:\Data_Stam\210228IF_210225exp_Mdc1_Fixed\cov2_53BP1NB\segmentations_100\fov_7\cell_4_incoporated_chr.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:105: UserWarning: E:\Data_Stam\210228IF_210225exp_Mdc1_Fixed\cov2_53BP1NB\segmentations_100\fov_7\cell_4_incoporated_chr.tif is a low contrast image
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:106: UserWarning: E:\Data_Stam\210228IF_210225exp_Mdc1_Fixed\cov2_53BP1NB\segmentations_100\fov_7\cell_4_control_chr_cell.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# Analyzing the plane 3 for the image 8 in this dataset
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:105: UserWarning: E:\Data_Stam\210228IF_210225exp_Mdc1_Fixed\cov2_53BP1NB\segmentations_100\fov_8\cell_2_incoporated_chr.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:105: UserWarning: E:\Data_Stam\210228IF_210225exp_Mdc1_Fixed\cov2_53BP1NB\segmentations_100\fov_8\cell_2_incoporated_chr.tif is a low contrast image
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:106: UserWarning: E:\Data_Stam\210228IF_210225exp_Mdc1_Fixed\cov2_53BP1NB\segmentations_100\fov_8\cell_2_control_chr_cell.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:105: UserWarning: E:\Data_Stam\210228IF_210225exp_Mdc1_Fixed\cov2_53BP1NB\segmentations_100\fov_8\cell_3_incoporated_chr.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:105: UserWarning: E:\Data_Stam\210228IF_210225exp_Mdc1_Fixed\cov2_53BP1NB\segmentations_100\fov_8\cell_3_incoporated_chr.tif is a low contrast image
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:106: UserWarning: E:\Data_Stam\210228IF_210225exp_Mdc1_Fixed\cov2_53BP1NB\segmentations_100\fov_8\cell_3_control_chr_cell.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# Analyzing the plane 7 for the image 9 in this dataset
# Analyzing the plane 7 for the image 10 in this dataset
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:105: UserWarning: E:\Data_Stam\210228IF_210225exp_Mdc1_Fixed\cov2_53BP1NB\segmentations_100\fov_10\cell_0_incoporated_chr.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:105: UserWarning: E:\Data_Stam\210228IF_210225exp_Mdc1_Fixed\cov2_53BP1NB\segmentations_100\fov_10\cell_0_incoporated_chr.tif is a low contrast image
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:106: UserWarning: E:\Data_Stam\210228IF_210225exp_Mdc1_Fixed\cov2_53BP1NB\segmentations_100\fov_10\cell_0_control_chr_cell.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:105: UserWarning: E:\Data_Stam\210228IF_210225exp_Mdc1_Fixed\cov2_53BP1NB\segmentations_100\fov_10\cell_1_incoporated_chr.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:105: UserWarning: E:\Data_Stam\210228IF_210225exp_Mdc1_Fixed\cov2_53BP1NB\segmentations_100\fov_10\cell_1_incoporated_chr.tif is a low contrast image
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:106: UserWarning: E:\Data_Stam\210228IF_210225exp_Mdc1_Fixed\cov2_53BP1NB\segmentations_100\fov_10\cell_1_control_chr_cell.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# Analyzing the plane 3 for the image 11 in this dataset
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:105: UserWarning: E:\Data_Stam\210228IF_210225exp_Mdc1_Fixed\cov2_53BP1NB\segmentations_100\fov_11\cell_0_incoporated_chr.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:105: UserWarning: E:\Data_Stam\210228IF_210225exp_Mdc1_Fixed\cov2_53BP1NB\segmentations_100\fov_11\cell_0_incoporated_chr.tif is a low contrast image
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:106: UserWarning: E:\Data_Stam\210228IF_210225exp_Mdc1_Fixed\cov2_53BP1NB\segmentations_100\fov_11\cell_0_control_chr_cell.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:105: UserWarning: E:\Data_Stam\210228IF_210225exp_Mdc1_Fixed\cov2_53BP1NB\segmentations_100\fov_11\cell_1_incoporated_chr.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:105: UserWarning: E:\Data_Stam\210228IF_210225exp_Mdc1_Fixed\cov2_53BP1NB\segmentations_100\fov_11\cell_1_incoporated_chr.tif is a low contrast image
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:106: UserWarning: E:\Data_Stam\210228IF_210225exp_Mdc1_Fixed\cov2_53BP1NB\segmentations_100\fov_11\cell_1_control_chr_cell.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# Analyzing the plane 5 for the image 12 in this dataset
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:105: UserWarning: E:\Data_Stam\210228IF_210225exp_Mdc1_Fixed\cov2_53BP1NB\segmentations_100\fov_12\cell_0_incoporated_chr.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:105: UserWarning: E:\Data_Stam\210228IF_210225exp_Mdc1_Fixed\cov2_53BP1NB\segmentations_100\fov_12\cell_0_incoporated_chr.tif is a low contrast image
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:106: UserWarning: E:\Data_Stam\210228IF_210225exp_Mdc1_Fixed\cov2_53BP1NB\segmentations_100\fov_12\cell_0_control_chr_cell.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:105: UserWarning: E:\Data_Stam\210228IF_210225exp_Mdc1_Fixed\cov2_53BP1NB\segmentations_100\fov_12\cell_1_incoporated_chr.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:105: UserWarning: E:\Data_Stam\210228IF_210225exp_Mdc1_Fixed\cov2_53BP1NB\segmentations_100\fov_12\cell_1_incoporated_chr.tif is a low contrast image
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:106: UserWarning: E:\Data_Stam\210228IF_210225exp_Mdc1_Fixed\cov2_53BP1NB\segmentations_100\fov_12\cell_1_control_chr_cell.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# Analyzing the plane 2 for the image 13 in this dataset
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:105: UserWarning: E:\Data_Stam\210228IF_210225exp_Mdc1_Fixed\cov2_53BP1NB\segmentations_100\fov_13\cell_0_incoporated_chr.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:105: UserWarning: E:\Data_Stam\210228IF_210225exp_Mdc1_Fixed\cov2_53BP1NB\segmentations_100\fov_13\cell_0_incoporated_chr.tif is a low contrast image
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:106: UserWarning: E:\Data_Stam\210228IF_210225exp_Mdc1_Fixed\cov2_53BP1NB\segmentations_100\fov_13\cell_0_control_chr_cell.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# Analyzing the plane 7 for the image 14 in this dataset
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:105: UserWarning: E:\Data_Stam\210228IF_210225exp_Mdc1_Fixed\cov2_53BP1NB\segmentations_100\fov_14\cell_0_incoporated_chr.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:105: UserWarning: E:\Data_Stam\210228IF_210225exp_Mdc1_Fixed\cov2_53BP1NB\segmentations_100\fov_14\cell_0_incoporated_chr.tif is a low contrast image
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:106: UserWarning: E:\Data_Stam\210228IF_210225exp_Mdc1_Fixed\cov2_53BP1NB\segmentations_100\fov_14\cell_0_control_chr_cell.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:105: UserWarning: E:\Data_Stam\210228IF_210225exp_Mdc1_Fixed\cov2_53BP1NB\segmentations_100\fov_14\cell_2_incoporated_chr.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:105: UserWarning: E:\Data_Stam\210228IF_210225exp_Mdc1_Fixed\cov2_53BP1NB\segmentations_100\fov_14\cell_2_incoporated_chr.tif is a low contrast image
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:106: UserWarning: E:\Data_Stam\210228IF_210225exp_Mdc1_Fixed\cov2_53BP1NB\segmentations_100\fov_14\cell_2_control_chr_cell.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# Analyzing the plane 2 for the image 15 in this dataset
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:105: UserWarning: E:\Data_Stam\210228IF_210225exp_Mdc1_Fixed\cov2_53BP1NB\segmentations_100\fov_15\cell_0_incoporated_chr.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:105: UserWarning: E:\Data_Stam\210228IF_210225exp_Mdc1_Fixed\cov2_53BP1NB\segmentations_100\fov_15\cell_0_incoporated_chr.tif is a low contrast image
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:106: UserWarning: E:\Data_Stam\210228IF_210225exp_Mdc1_Fixed\cov2_53BP1NB\segmentations_100\fov_15\cell_0_control_chr_cell.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:105: UserWarning: E:\Data_Stam\210228IF_210225exp_Mdc1_Fixed\cov2_53BP1NB\segmentations_100\fov_15\cell_1_incoporated_chr.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:105: UserWarning: E:\Data_Stam\210228IF_210225exp_Mdc1_Fixed\cov2_53BP1NB\segmentations_100\fov_15\cell_1_incoporated_chr.tif is a low contrast image
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:106: UserWarning: E:\Data_Stam\210228IF_210225exp_Mdc1_Fixed\cov2_53BP1NB\segmentations_100\fov_15\cell_1_control_chr_cell.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:105: UserWarning: E:\Data_Stam\210228IF_210225exp_Mdc1_Fixed\cov2_53BP1NB\segmentations_100\fov_15\cell_2_incoporated_chr.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:105: UserWarning: E:\Data_Stam\210228IF_210225exp_Mdc1_Fixed\cov2_53BP1NB\segmentations_100\fov_15\cell_2_incoporated_chr.tif is a low contrast image
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:106: UserWarning: E:\Data_Stam\210228IF_210225exp_Mdc1_Fixed\cov2_53BP1NB\segmentations_100\fov_15\cell_2_control_chr_cell.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# Analyzing the plane 4 for the image 16 in this dataset
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:105: UserWarning: E:\Data_Stam\210228IF_210225exp_Mdc1_Fixed\cov2_53BP1NB\segmentations_100\fov_16\cell_2_incoporated_chr.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:105: UserWarning: E:\Data_Stam\210228IF_210225exp_Mdc1_Fixed\cov2_53BP1NB\segmentations_100\fov_16\cell_2_incoporated_chr.tif is a low contrast image
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:106: UserWarning: E:\Data_Stam\210228IF_210225exp_Mdc1_Fixed\cov2_53BP1NB\segmentations_100\fov_16\cell_2_control_chr_cell.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# Analyzing the plane 2 for the image 17 in this dataset
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:105: UserWarning: E:\Data_Stam\210228IF_210225exp_Mdc1_Fixed\cov2_53BP1NB\segmentations_100\fov_17\cell_1_incoporated_chr.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:105: UserWarning: E:\Data_Stam\210228IF_210225exp_Mdc1_Fixed\cov2_53BP1NB\segmentations_100\fov_17\cell_1_incoporated_chr.tif is a low contrast image
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:106: UserWarning: E:\Data_Stam\210228IF_210225exp_Mdc1_Fixed\cov2_53BP1NB\segmentations_100\fov_17\cell_1_control_chr_cell.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:106: UserWarning: E:\Data_Stam\210228IF_210225exp_Mdc1_Fixed\cov2_53BP1NB\segmentations_100\fov_17\cell_1_control_chr_cell.tif is a low contrast image
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:105: UserWarning: E:\Data_Stam\210228IF_210225exp_Mdc1_Fixed\cov2_53BP1NB\segmentations_100\fov_17\cell_2_incoporated_chr.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:105: UserWarning: E:\Data_Stam\210228IF_210225exp_Mdc1_Fixed\cov2_53BP1NB\segmentations_100\fov_17\cell_2_incoporated_chr.tif is a low contrast image
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:106: UserWarning: E:\Data_Stam\210228IF_210225exp_Mdc1_Fixed\cov2_53BP1NB\segmentations_100\fov_17\cell_2_control_chr_cell.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:106: UserWarning: E:\Data_Stam\210228IF_210225exp_Mdc1_Fixed\cov2_53BP1NB\segmentations_100\fov_17\cell_2_control_chr_cell.tif is a low contrast image
# Analyzing the plane 1 for the image 18 in this dataset
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:105: UserWarning: E:\Data_Stam\210228IF_210225exp_Mdc1_Fixed\cov2_53BP1NB\segmentations_100\fov_18\cell_0_incoporated_chr.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:105: UserWarning: E:\Data_Stam\210228IF_210225exp_Mdc1_Fixed\cov2_53BP1NB\segmentations_100\fov_18\cell_0_incoporated_chr.tif is a low contrast image
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:106: UserWarning: E:\Data_Stam\210228IF_210225exp_Mdc1_Fixed\cov2_53BP1NB\segmentations_100\fov_18\cell_0_control_chr_cell.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# Analyzing the plane 3 for the image 19 in this dataset
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:105: UserWarning: E:\Data_Stam\210228IF_210225exp_Mdc1_Fixed\cov2_53BP1NB\segmentations_100\fov_19\cell_0_incoporated_chr.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:105: UserWarning: E:\Data_Stam\210228IF_210225exp_Mdc1_Fixed\cov2_53BP1NB\segmentations_100\fov_19\cell_0_incoporated_chr.tif is a low contrast image
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:106: UserWarning: E:\Data_Stam\210228IF_210225exp_Mdc1_Fixed\cov2_53BP1NB\segmentations_100\fov_19\cell_0_control_chr_cell.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:105: UserWarning: E:\Data_Stam\210228IF_210225exp_Mdc1_Fixed\cov2_53BP1NB\segmentations_100\fov_19\cell_1_incoporated_chr.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:105: UserWarning: E:\Data_Stam\210228IF_210225exp_Mdc1_Fixed\cov2_53BP1NB\segmentations_100\fov_19\cell_1_incoporated_chr.tif is a low contrast image
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:106: UserWarning: E:\Data_Stam\210228IF_210225exp_Mdc1_Fixed\cov2_53BP1NB\segmentations_100\fov_19\cell_1_control_chr_cell.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:105: UserWarning: E:\Data_Stam\210228IF_210225exp_Mdc1_Fixed\cov2_53BP1NB\segmentations_100\fov_19\cell_2_incoporated_chr.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:105: UserWarning: E:\Data_Stam\210228IF_210225exp_Mdc1_Fixed\cov2_53BP1NB\segmentations_100\fov_19\cell_2_incoporated_chr.tif is a low contrast image
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:106: UserWarning: E:\Data_Stam\210228IF_210225exp_Mdc1_Fixed\cov2_53BP1NB\segmentations_100\fov_19\cell_2_control_chr_cell.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:105: UserWarning: E:\Data_Stam\210228IF_210225exp_Mdc1_Fixed\cov2_53BP1NB\segmentations_100\fov_19\cell_3_incoporated_chr.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:105: UserWarning: E:\Data_Stam\210228IF_210225exp_Mdc1_Fixed\cov2_53BP1NB\segmentations_100\fov_19\cell_3_incoporated_chr.tif is a low contrast image
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:106: UserWarning: E:\Data_Stam\210228IF_210225exp_Mdc1_Fixed\cov2_53BP1NB\segmentations_100\fov_19\cell_3_control_chr_cell.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:106: UserWarning: E:\Data_Stam\210228IF_210225exp_Mdc1_Fixed\cov2_53BP1NB\segmentations_100\fov_19\cell_3_control_chr_cell.tif is a low contrast image
# Analyzing the plane 4 for the image 20 in this dataset
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:105: UserWarning: E:\Data_Stam\210228IF_210225exp_Mdc1_Fixed\cov2_53BP1NB\segmentations_100\fov_20\cell_0_incoporated_chr.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:105: UserWarning: E:\Data_Stam\210228IF_210225exp_Mdc1_Fixed\cov2_53BP1NB\segmentations_100\fov_20\cell_0_incoporated_chr.tif is a low contrast image
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:106: UserWarning: E:\Data_Stam\210228IF_210225exp_Mdc1_Fixed\cov2_53BP1NB\segmentations_100\fov_20\cell_0_control_chr_cell.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# Analyzing the plane 5 for the image 21 in this dataset
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:105: UserWarning: E:\Data_Stam\210228IF_210225exp_Mdc1_Fixed\cov2_53BP1NB\segmentations_100\fov_21\cell_0_incoporated_chr.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:105: UserWarning: E:\Data_Stam\210228IF_210225exp_Mdc1_Fixed\cov2_53BP1NB\segmentations_100\fov_21\cell_0_incoporated_chr.tif is a low contrast image
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:106: UserWarning: E:\Data_Stam\210228IF_210225exp_Mdc1_Fixed\cov2_53BP1NB\segmentations_100\fov_21\cell_0_control_chr_cell.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:105: UserWarning: E:\Data_Stam\210228IF_210225exp_Mdc1_Fixed\cov2_53BP1NB\segmentations_100\fov_21\cell_1_incoporated_chr.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:105: UserWarning: E:\Data_Stam\210228IF_210225exp_Mdc1_Fixed\cov2_53BP1NB\segmentations_100\fov_21\cell_1_incoporated_chr.tif is a low contrast image
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:106: UserWarning: E:\Data_Stam\210228IF_210225exp_Mdc1_Fixed\cov2_53BP1NB\segmentations_100\fov_21\cell_1_control_chr_cell.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# Analyzing the plane 1 for the image 22 in this dataset
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:105: UserWarning: E:\Data_Stam\210228IF_210225exp_Mdc1_Fixed\cov2_53BP1NB\segmentations_100\fov_22\cell_1_incoporated_chr.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:105: UserWarning: E:\Data_Stam\210228IF_210225exp_Mdc1_Fixed\cov2_53BP1NB\segmentations_100\fov_22\cell_1_incoporated_chr.tif is a low contrast image
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:106: UserWarning: E:\Data_Stam\210228IF_210225exp_Mdc1_Fixed\cov2_53BP1NB\segmentations_100\fov_22\cell_1_control_chr_cell.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:106: UserWarning: E:\Data_Stam\210228IF_210225exp_Mdc1_Fixed\cov2_53BP1NB\segmentations_100\fov_22\cell_1_control_chr_cell.tif is a low contrast image
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:105: UserWarning: E:\Data_Stam\210228IF_210225exp_Mdc1_Fixed\cov2_53BP1NB\segmentations_100\fov_22\cell_2_incoporated_chr.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:105: UserWarning: E:\Data_Stam\210228IF_210225exp_Mdc1_Fixed\cov2_53BP1NB\segmentations_100\fov_22\cell_2_incoporated_chr.tif is a low contrast image
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:106: UserWarning: E:\Data_Stam\210228IF_210225exp_Mdc1_Fixed\cov2_53BP1NB\segmentations_100\fov_22\cell_2_control_chr_cell.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:105: UserWarning: E:\Data_Stam\210228IF_210225exp_Mdc1_Fixed\cov2_53BP1NB\segmentations_100\fov_22\cell_3_incoporated_chr.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:105: UserWarning: E:\Data_Stam\210228IF_210225exp_Mdc1_Fixed\cov2_53BP1NB\segmentations_100\fov_22\cell_3_incoporated_chr.tif is a low contrast image
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:106: UserWarning: E:\Data_Stam\210228IF_210225exp_Mdc1_Fixed\cov2_53BP1NB\segmentations_100\fov_22\cell_3_control_chr_cell.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# Analyzing the plane 2 for the image 23 in this dataset
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:105: UserWarning: E:\Data_Stam\210228IF_210225exp_Mdc1_Fixed\cov2_53BP1NB\segmentations_100\fov_23\cell_0_incoporated_chr.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:105: UserWarning: E:\Data_Stam\210228IF_210225exp_Mdc1_Fixed\cov2_53BP1NB\segmentations_100\fov_23\cell_0_incoporated_chr.tif is a low contrast image
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:106: UserWarning: E:\Data_Stam\210228IF_210225exp_Mdc1_Fixed\cov2_53BP1NB\segmentations_100\fov_23\cell_0_control_chr_cell.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# Analyzing the plane 3 for the image 24 in this dataset
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:105: UserWarning: E:\Data_Stam\210228IF_210225exp_Mdc1_Fixed\cov2_53BP1NB\segmentations_100\fov_24\cell_0_incoporated_chr.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:105: UserWarning: E:\Data_Stam\210228IF_210225exp_Mdc1_Fixed\cov2_53BP1NB\segmentations_100\fov_24\cell_0_incoporated_chr.tif is a low contrast image
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:106: UserWarning: E:\Data_Stam\210228IF_210225exp_Mdc1_Fixed\cov2_53BP1NB\segmentations_100\fov_24\cell_0_control_chr_cell.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.

# %% [markdown]
# # Define channel information to save measurements as excel here:

# %%
# Replace the protein/dna name below as how they are ordered for the channel (ch405, ch488, ch560, ch647)
# For example, ch_save_list = ["dna","rpa2","mdc1","pol2S5"] if rpa2 in ch488
ch_save_list = ["dna","53BP1NB","mdc1","pol2S5"]

ch1 = ch_save_list[0]
ch2 = ch_save_list[1]
ch3 = ch_save_list[2]
ch4 = ch_save_list[3]

# %%
import pandas as pd


df = pd.DataFrame(measurement_for_all_fov)  
df.columns = ['fov_id','cell_id','area_incorporated_chr','area_control_chr','area_nucleolus',
             f'ave_intensity_incorporated_chr_{ch1}',f'ave_intensity_control_chr_{ch1}',f'ave_intensity_nucleolus_{ch1}',
# 42                           544.179161                      210.150322
# 43                            67.049313                        7.821439
#
#     ave_intensity_nucleolus_mdc1  ave_intensity_incorporated_chr_pol2S5  \
# 0                      58.198902                             171.361483
# 1                      36.516434                              36.819521
# 2                      52.608290                             220.779481
# 3                      62.565457                             216.024471
# 4                      44.723399                             166.753393
# 5                      41.623249                             202.583531
# 6                      10.675074                              33.832623
# 7                      29.154189                              89.740779
# 8                      78.066917                             165.032926
# 9                      35.487871                             397.888505
# 10                     16.584927                             149.628179
# 11                     65.286070                             143.262152
# 12                     31.440979                              57.420324
# 13                     11.283795                              73.139020
# 14                      8.023051                              66.169394
# 15                     12.677874                              54.195437
# 16                     12.867721                             129.321263
# 17                      3.820969                              31.363683
# 18                     11.413396                             188.969901
# 19                      7.169827                              83.135508
# 20                     10.734690                             186.545811
# 21                      6.381858                              80.751077
# 22                     -3.099721                              50.126044
# 23                     17.464428                              94.703115
# 24                      3.585817                              41.273918
# 25                      5.077333                              27.083244
# 26                     14.222003                              49.833570
# 27                     33.721049                              87.671162
# 28                     39.079460                              87.293074
# 29                     11.102699                             101.330657
# 30                     15.436549                              68.162356
# 31                      5.207271                             146.021889
# 32                     18.270053                              39.139710
# 33                      7.813144                              80.836489
# 34                     29.667411                              69.250793
# 35                     16.022950                             134.648290
# 36                     11.663365                              88.796990
# 37                     10.561915                              97.781024
# 38                      6.524234                              89.407360
# 39                     53.205449                             118.157645
# 40                     35.833085                              51.422432
# 41                     71.934283                             217.571775
# 42                     95.785039                              47.558811
# 43                      3.660501                             103.372955
#
#     ave_intensity_control_chr_pol2S5  ave_intensity_nucleolus_pol2S5
# 0                         244.305456                      103.064294
# 1                          81.673977                       44.916382
# 2                         245.533004                       71.152067
# 3                         347.928268                      111.805958
# 4                         244.883053                      103.444020
# 5                         308.169062                      116.079952
# 6                          60.449420                       39.089854
# 7                         127.362102                       50.037181
# 8                         270.936942                       75.983678
# 9                         373.315730                      143.216770
# 10                        234.342965                      109.435733
# 11                        154.214307                       47.694441
# 12                         97.041823                       28.630172
# 13                        127.007701                       40.059444
# 14                         79.666987                       31.718201
# 15                         89.159779                       36.090640
# 16                        129.145048                       69.455673
# 17                         60.427354                       35.408297
# 18                        186.294184                       60.792237
# 19                        144.358837                       65.357247
# 20                        186.147870                       70.952528
# 21                        141.591984                       68.585877
# 22                         64.217081                       64.725294
# 23                        134.895774                       44.850664
# 24                         68.564706                       33.053396
# 25                         38.874450                       24.950470
# 26                         73.564663                       30.969119
# 27                        141.573350                       40.955956
# 28                        112.027150                       27.052854
# 29                         89.657993                       41.142031
# 30                        154.490412                       76.169146
# 31                        194.057666                       59.510470
# 32                         81.899232                       46.895921
# 33                        106.098783                       35.682598
# 34                        125.915937                       65.142022
# 35                        252.153206                       95.727723
# 36                        127.503359                       79.996519
# 37                        136.825460                       88.510992
# 38                        147.826471                       69.041396
# 39                        125.214935                       24.621959
# 40                         38.477681                       16.839225
# 41                        242.790373                       63.624506
# 42                        150.242221                       62.811209
# 43                        161.722196                       81.759516
