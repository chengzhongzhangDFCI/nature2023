# %% [markdown]
# ## Import required modules

# %%
import numpy as np
import matplotlib.pyplot as plt
from skimage import io
from skimage import data
import skimage
from skimage.filters.thresholding import threshold_li,threshold_local,threshold_otsu
from skimage.morphology import erosion, dilation, opening, closing, white_tophat, remove_small_objects, ball
from skimage.morphology import disk
from scipy import ndimage as ndi
import sys,os, glob

#import skimage.filters.median

#import skimage.segmentation as seg
#import skimage.filters as filters
#import skimage.draw as draw
#import skimage.color as color

#from skimage.filters.thresholding import _cross_entropy
#from skimage.morphology import black_tophat, skeletonize, convex_hull_image


#pip install nd2reader_required for nd2 file reading
from nd2reader import ND2Reader

import pandas as pd

# for dna segmentation
import cellpose
from cellpose import models

# %% [markdown]
# ## Load data to analyze

# %%
data_save_folder = r"D:\Analyzed_CellBio\Stam\Lac_Ms_live\*"

data_main_folder = r"D:\Analyzed_CellBio\Stam\Lac_Ms_live"

analysis_prefix = 'Lac_Ms2'
############################# CHANGE WELL FOR DATA OF INTEREST HERE!##########################################


data_folder = data_save_folder
#data_files = [file for file in glob.glob(data_folder) if "z2.tif" in file]
data_files = [file for file in glob.glob(data_folder) if "nd" in file]
data_files
# Out:
# ['D:\\Analyzed_CellBio\\Stam\\Lac_Ms_live\\210825 263 H2B-G LacI-548 Ms2-647 noco__crop_Pos19.nd2',
#  'D:\\Analyzed_CellBio\\Stam\\Lac_Ms_live\\210830 263 H2B-G LacI-548 Ms2-647 noco__crop_Pos11.nd2',
#  'D:\\Analyzed_CellBio\\Stam\\Lac_Ms_live\\210830 263 H2B-G LacI-548 Ms2-647 noco__crop_Pos6.nd2']

# %%
images = ND2Reader(data_files[1])

# %% [markdown]
# ## Define basic function for analysis

# %%
    num_of_nuclei = len(np.unique(dna_masks)) - 1
    for i in range(num_of_nuclei):
        cand_nucleus = dna_masks == i+1
        cand_nucleus[cand_nucleus>0]=1
        cand_nucleus = np.array(cand_nucleus)
        
        
        
        region = skimage.measure.regionprops (skimage.measure.label(cand_nucleus))[0]
        
        _dist = np.linalg.norm(np.array([region.centroid[1], region.centroid[0]])
                                                    - np.array(dna_centroid))
        
        if _dist < found_dist:
            found_dist = _dist
            dna_masks = cand_nucleus

# %%
def segment_and_track_cell (images, 
                            cell_centroid = [176,103],
                            cell_area = 7000,
                            time = 0, 
                            z_selected = 1,
                            nuclei_filter = 600,
                            crop = True):

    
    
    # load 3d images for the timepoint selected
    image_dna = []
    for _lyr in range(images.sizes["z"]):
        lyr_dna = np.array(images.get_frame_2D (v=time, c=0, z=_lyr))[850:1190,850:1250]
        image_dna.append(lyr_dna)
        
    image_dna = np.array(image_dna)

    image_lac = []
    for _lyr in range(images.sizes["z"]):
        lyr_lac = np.array(images.get_frame_2D (v=time, c=1, z=_lyr))[850:1190,850:1250]
        image_lac.append(lyr_lac)
        
    image_lac = np.array(image_lac)  

    image_ms2 = []
    for _lyr in range(images.sizes["z"]):
        lyr_ms2 = np.array(images.get_frame_2D (v=time, c=2, z=_lyr))[850:1190,850:1250]
        image_ms2.append(lyr_ms2)
        
    image_ms2 = np.array(image_ms2)  
    
    # segment DAPI and track the cell
    
    model= models.Cellpose(gpu=False, model_type='nuclei')

    dna_masks, flows, styles, diams = model.eval(image_dna[z_selected], diameter=None, channels = [0,0],
                                         flow_threshold=0.4, do_3D=False)
    
    print(np.unique(dna_masks))
    dna_masks =  remove_small_objects(dna_masks, 100 ,connectivity=1)
    dna_masks = erosion(dna_masks, disk(20))
    dna_masks = dilation(dna_masks, disk(20))
    print(np.unique(dna_masks))
    
    found_dist = 600
    
    
    num_of_nuclei = len(np.unique(dna_masks)) - 1
    for i in range(num_of_nuclei):
        cand_nucleus = dna_masks == i+1
        cand_nucleus[cand_nucleus>0]=1
        cand_nucleus = np.array(cand_nucleus)
        
        
        
        region = skimage.measure.regionprops (skimage.measure.label(cand_nucleus))[0]
        
        _dist = np.linalg.norm(np.array([region.centroid[1], region.centroid[0]])
                                                    - np.array(cell_centroid))
        
        if _dist < found_dist:
            if abs(region.area - cell_area)/cell_area <=0.2:
                found_dist = _dist
                kept_nucleus = cand_nucleus
    
    
    region = skimage.measure.regionprops (skimage.measure.label(kept_nucleus))[0]    
    found_cell_centroid = [region.centroid[1], region.centroid[0]]
    found_cell_area = region.area
    
    return [kept_nucleus, found_cell_centroid, found_cell_area, found_dist]

# %%
# %matplotlib notebook
dna_masks =  remove_small_objects(dna_masks, 100 ,connectivity=1)
plt.imshow(dna_masks)
# Out:
# <img src="data:image/png;base64,..." width="638.888905813665">

# %%
region.area
# Out:
# 7677

# %%
found_object_info = segment_and_track_cell(images, time = 0)


print(found_object_info[1],found_object_info[2],found_object_info[3])

# %matplotlib notebook
plt.imshow(found_object_info[0])
# Out:
# >>>> using CPU
# Running test snippet to check if MKL-DNN working
# see https://pytorch.org/docs/stable/backends.html?highlight=mkl
# ** MKL version working - CPU version is sped up. **
# processing 1 image(s)
# computing styles from images
# time spent: running network 0.34s; flow+mask computation 0.06
# estimated cell diameters for 1 image(s) in 1.80 sec
# >>> diameter(s) =  [51.13981526]
# time spent: running network 1.30s; flow+mask computation 0.07
# estimated masks for 1 image(s) in 1.38 sec
# >>>> TOTAL TIME 3.17 sec
# [0 1 2 3]
# [0 1 2]
# [180.6756545525596, 102.31092874820894] 7677 4.726157496837801
# <img src="data:image/png;base64,..." width="638.888905813665">

# %%
for timepoint in range(61):
    
    if timepoint == 0:
        cell_centroid = [176,103],
        cell_area = 7000

    else:
        cell_centroid= found_object_info[1]
        cell_area =found_object_info[2]
    
    found_object_info = segment_and_track_cell(images, 
                                                time = timepoint, 
                                                cell_centroid=cell_centroid,
                                                cell_area =cell_area)
    
    
    print(found_object_info[1],found_object_info[2],found_object_info[3])
    # %matplotlib inline
    plt.imshow(found_object_info[0])
# Out:
# >>>> using CPU
# Running test snippet to check if MKL-DNN working
# see https://pytorch.org/docs/stable/backends.html?highlight=mkl
# ** MKL version working - CPU version is sped up. **
# processing 1 image(s)
# computing styles from images
# time spent: running network 0.34s; flow+mask computation 0.08
# estimated cell diameters for 1 image(s) in 1.80 sec
# >>> diameter(s) =  [51.13981526]
# time spent: running network 1.30s; flow+mask computation 0.07
# estimated masks for 1 image(s) in 1.38 sec
# >>>> TOTAL TIME 3.18 sec
# [0 1 2 3]
# [0 1 2]
# [180.6756545525596, 102.31092874820894] 7677 4.726157496837801
# >>>> using CPU
# Running test snippet to check if MKL-DNN working
# see https://pytorch.org/docs/stable/backends.html?highlight=mkl
# ** MKL version working - CPU version is sped up. **
# processing 1 image(s)
# computing styles from images
# time spent: running network 0.33s; flow+mask computation 0.07
# estimated cell diameters for 1 image(s) in 1.80 sec
# ...

# %%
# %matplotlib inline
plt.imshow(found_object_info[0])

# %%
_verbose = True
found_dist = 600

dna_centroid = [176,103]
if _verbose:
    num_of_nuclei = len(np.unique(dna_masks)) - 1
    for i in range(num_of_nuclei):
        cand_nucleus = dna_masks == i+1
        #cand_nucleus[cand_nucleus>0]=1
        cand_nucleus = np.array(cand_nucleus)
        
        print(i)
        
        
        
        region = skimage.measure.regionprops (skimage.measure.label(cand_nucleus))[0]
        
        _dist = np.linalg.norm(np.array([region.centroid[1], region.centroid[0]])
                                                    - np.array(dna_centroid))
        
        if _dist < found_dist:
            found_dist = _dist
            dna_masks = cand_nucleus
# Out:
# 0

# %%
found_dist
# Out:
# 4.726157496837801

# %%
images = ND2Reader(data_files[1])

images.sizes.keys()

images.sizes["t"]

image_dna = np.array(images.get_frame_2D (v=0, c=1, z=1))[850:1190,850:1250]
# %matplotlib notebook
plt.imshow(image_dna)

image_dna
# Out:
# <img src="data:image/png;base64,..." width="638.888905813665">
# array([[ 98, 103, 103, ..., 108, 104, 104],
#        [108, 111, 104, ..., 107, 109, 107],
#        [106, 109, 110, ..., 106, 106, 106],
#        ...,
#        [102, 110, 106, ..., 104, 108, 107],
#        [106, 108, 107, ..., 108,  99, 102],
#        [103, 111, 107, ..., 109,  99, 106]], dtype=uint16)

# %%
image_dna = np.array(images.get_frame_2D (v=60, c=0, z=1))[850:1190,850:1250]
# %matplotlib notebook
plt.imshow(image_dna)
# Out:
# <img src="data:image/png;base64,..." width="638.888905813665">

# %%
from skimage.filters import try_all_threshold
image_lac = np.array(images.get_frame_2D (v=90, c=1, z=1))[850:1190,850:1250]

image_ms2 = np.array(images.get_frame_2D (v=90, c=2, z=1))[850:1190,850:1250]

fig, ax = try_all_threshold(image_lac, figsize=(10, 8), verbose=False)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="998.8889153504084">
