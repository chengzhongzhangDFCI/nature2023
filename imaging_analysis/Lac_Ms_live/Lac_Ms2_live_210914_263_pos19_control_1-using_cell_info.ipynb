# %% [markdown]
# ## Import required modules

# %%
import numpy as np
import matplotlib.pyplot as plt
from skimage import io
from skimage import data
import skimage
from skimage.filters.thresholding import threshold_li,threshold_local,threshold_otsu, threshold_yen
from skimage.morphology import erosion, dilation, opening, closing, white_tophat, remove_small_objects, ball
from skimage.morphology import disk
from scipy import ndimage as ndi
import sys,os, glob

#import skimage.filters.median

#import skimage.segmentation as seg
#import skimage.filters as filters
#import skimage.draw as draw
#import skimage.color as color

#from skimage.filters.thresholding import _cross_entropy
#from skimage.morphology import black_tophat, skeletonize, convex_hull_image


#pip install nd2reader_required for nd2 file reading
from nd2reader import ND2Reader

import pandas as pd

# for dna segmentation
import cellpose
from cellpose import models
# Out:
# c:\programdata\anaconda3\lib\site-packages\skimage\io\manage_plugins.py:23: UserWarning: Your installed pillow version is < 7.1.0. Several security issues (CVE-2020-11538, CVE-2020-10379, CVE-2020-10994, CVE-2020-10177) have been fixed in pillow 7.1.0 or higher. We recommend to upgrade this library.
#   from .collection import imread_collection_wrapper

# %% [markdown]
# ## Load data to analyze

# %% [markdown]
# ### 1. Load images

# %%
# Define data loading and saving folder

# path to glob
data_save_folder = r"D:\Analyzed_CellBio\Stam\Lac_Ms_live\210914_263_pos19\*"

# path to save results
data_main_folder = r"D:\Analyzed_CellBio\Stam\Lac_Ms_live\210914_263_pos19"

# not used here
analysis_prefix = 'Lac_Ms2'
############################# CHANGE WELL FOR DATA OF INTEREST HERE!##########################################


data_folder = data_save_folder
#data_files = [file for file in glob.glob(data_folder) if "z2.tif" in file]
data_files = [file for file in glob.glob(data_folder) if "nd" in file]
data_files



# load cell info for analysis

cell_name = 'control_1'

# %% [markdown]
# ### 2. Cropp and saved cropped images

# %%
#%matplotlib notebook
#image_test =np.array(images.get_frame_2D (v=0, c=0, z=1))
#plt.imshow(image_test)

# %%
# load images and get data name for the nd2 file
images = ND2Reader(data_files[0])
data_name = data_files[0].split('\\')[-1].split('.nd2')[0]

#images.sizes["t"]
# define the cropping coord inverted (input number are xy as seen in ImageJ)
#crop_x1, crop_x2, crop_y1, crop_y2 = 756,1146,819,1089 # x1-2, then y1-2


crop_x1, crop_x2, crop_y1, crop_y2 =309,1002,1139,1967

# z for analyze
z_selected = 1

#save cropped images or not
# ch-t-z-xy
_save_crop_image =True

if _save_crop_image:
    crop_image_ch_all = {}

    for ind, ch in enumerate(range(images.sizes["c"])):
        image_ch_all = []
    
        for timepoint in range(images.sizes["t"]):
            image_ch =np.array(images.get_frame_2D (v=timepoint, c=ch, z=z_selected))[crop_y1: crop_y2, crop_x1: crop_x2]
        
        #for _lyr in range(images.sizes["z"]):
            #lyr_ch = np.array(images.get_frame_2D (v=timepoint, c=ch, z=_lyr))[840:1200,850:1250]
            #image_ch.append(lyr_ch)
            
            image_ch_all.append(image_ch)
        
        crop_image_ch_all[ind] = np.array(image_ch_all)    

    raw_cell_path = data_main_folder + os.sep + f'raw_{cell_name}'
    if not os.path.exists(raw_cell_path):
        os.mkdir(raw_cell_path)

    savename_list = [raw_cell_path + os.sep + f'{data_name}_{cell_name}_DNA.tif',
                   raw_cell_path + os.sep + f'{data_name}_{cell_name}_lac.tif',
                   raw_cell_path + os.sep + f'{data_name}_{cell_name}_ms2.tif']

    for ind, save_name in enumerate(savename_list):
        if os.path.exists(save_name):
            os.remove(save_name)
        io.imsave(save_name, crop_image_ch_all[ind])
# Out:
# C:\Users\Shiwei\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:47: UserWarning: D:\Analyzed_CellBio\Stam\Lac_Ms_live\210914_263_pos19\raw_control_1\210914_263_pos19_control_1_DNA.tif is a low contrast image
# C:\Users\Shiwei\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:47: UserWarning: D:\Analyzed_CellBio\Stam\Lac_Ms_live\210914_263_pos19\raw_control_1\210914_263_pos19_control_1_lac.tif is a low contrast image
# C:\Users\Shiwei\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:47: UserWarning: D:\Analyzed_CellBio\Stam\Lac_Ms_live\210914_263_pos19\raw_control_1\210914_263_pos19_control_1_ms2.tif is a low contrast image

# %% [markdown]
# ### 3. Other parameters and cell info

# %%
# Define some shared parameters here

# the dilation for measuring the foci
_foci_measure_size = 2

nuclei_filter = 600
foci_filter = 10

use_STD_foci_segmentation = False

# %%
# load cell info for analysis


cell_info = pd.read_excel(data_main_folder + os.sep + f'{data_name}_cell_info_{cell_name}.xlsx')

cell_info
# Out:
#    timepoint  cell X  cell Y  cell area  lac X  lac Y stage
# 0          1   193.0   696.0     7000.0  164.0  737.0     1
# 1         59     NaN     NaN        NaN    NaN    NaN     m
# 2         63   406.0   448.0     7000.0  436.0  461.0     2
# 3         66   406.0   473.0     7000.0  436.0  478.0   NaN

# %%
# Define timepoints duration based on cell info

_all_time_points = range(images.sizes["t"])

_first_duration = range(int(cell_info[cell_info['stage'] == 1]['timepoint'])-1,
                        int(cell_info[cell_info['stage'] == 'm']['timepoint'])-1)

_mitosis_duration = range(int(cell_info[cell_info['stage'] == 'm']['timepoint']-1),
                        int(cell_info[cell_info['stage'] == 2]['timepoint'])-1)

_second_duration = range(int(cell_info[cell_info['stage'] == 2]['timepoint'])-1,
                        images.sizes["t"])

if len(cell_info[cell_info['stage'] == 'e'])>0:
    _end_time_point = int(cell_info[cell_info['stage'] == 'e']['timepoint'])-1

    if _end_time_point >0 and _end_time_point <images.sizes["t"]:
        _all_time_points = range(0, _end_time_point)
        
if len(cell_info[cell_info['stage'] == 's'])>0:
    _skip_time_points =  []
    for _t in cell_info[cell_info['stage'] == 's']['timepoint']:
        _skip_time_points.append(int(_t)-1)
    
    _all_time_points = [_t for _t in _all_time_points if _t not in _skip_time_points]

#_first_duration
#_mitosis_duration
#_second_duration


# Define cell centorid, etc., for annotated timepoints based on cell info

annotated_timepoints = {}


for _item in cell_info.iloc():
    
    annotated_timepoints[_item['timepoint']] = {}
    annotated_timepoints[_item['timepoint']]['cell_centroid']=[_item['cell X'],_item['cell Y']]
    annotated_timepoints[_item['timepoint']]['cell_area']=_item['cell area']
    annotated_timepoints[_item['timepoint']]['foci_centroid']=[_item['lac X'],_item['lac Y']]

annotated_timepoints
# Out:
# {1: {'cell_centroid': [193.0, 696.0],
#   'cell_area': 7000.0,
#   'foci_centroid': [164.0, 737.0]},
#  59: {'cell_centroid': [nan, nan],
#   'cell_area': nan,
#   'foci_centroid': [nan, nan]},
#  63: {'cell_centroid': [406.0, 448.0],
#   'cell_area': 7000.0,
#   'foci_centroid': [436.0, 461.0]},
#  66: {'cell_centroid': [406.0, 473.0],
#   'cell_area': 7000.0,
#   'foci_centroid': [436.0, 478.0]}}

# %%
_all_time_points
# Out:
# range(0, 90)

# %% [markdown]
# ##  Analysis for cell of interest

# %% [markdown]
# ### 1. Define basic function for analysis

# %%
def segment_and_track_object (images, ch_index,
                            object_centroid = [176,103],
                              ref_centroid = [],
                            object_area = 7000,
                            time = 0,     
                            search_dist = 600,
                            z_selected = 1,
                            nuclei_filter = 600,
                              foci_filter = 20,
                            mode = 'nuclei',
                              foci_segmentation = 'Yen',
                              cell_mask = None,
                              use_area = True,
                            crop = True,
                             crop_x1=0,crop_x2=2048,crop_y1=0,crop_y2=2048,
                             saved_object_mask =[]):

    
    
    # load 3d images for the channel and z plane selected
    image_ch = []
    for _lyr in range(images.sizes["z"]):
        lyr_ch = np.array(images.get_frame_2D (v=time, c=ch_index-1, z=_lyr))[crop_y1: crop_y2, crop_x1: crop_x2]
        image_ch.append(lyr_ch)
        
    image_ch = np.array(image_ch)

    # use cellpose for nuclei segmentation  
    if mode == 'nuclei':
     # segment DAPI and track the cell
        model= models.Cellpose(gpu=False, model_type=mode)
        
        # adjust nuclear diameter as 100
        object_masks, flows, styles, diams = model.eval(image_ch[z_selected], diameter=100, channels = [0,0],
                                         flow_threshold=0.4, do_3D=False)
    
        
        object_masks =  remove_small_objects(object_masks, nuclei_filter ,connectivity=1)
        # erosion to remove abutting micronuclei
        object_masks = erosion(object_masks, disk(20))
        object_masks = dilation(object_masks, disk(20))

    # use Yen thresholding for lac foci segmentation
    if mode == 'foci':
        if foci_segmentation == 'Yen':
            object_masks = image_ch[z_selected] > threshold_yen(image_ch[z_selected])
            # remove small less confident foci
            object_masks = dilation(object_masks)
            object_masks = remove_small_objects(object_masks,foci_filter+5)
            object_masks = skimage.measure.label(object_masks)
        elif foci_segmentation == 'STD' and cell_mask is not None:
            foci_intensity = dilation(cell_mask) * image_ch[z_selected]
            foci_intensity_filtered = foci_intensity[foci_intensity!=0]
            foci_positive_th =np.mean(foci_intensity_filtered) + np.std(foci_intensity_filtered)*3

            foci_mask = (image_ch[z_selected] > foci_positive_th)*cell_mask
            object_masks = remove_small_objects(foci_mask, foci_filter)
            
        
    # initiate search distances
    found_dist = search_dist
    combined_dist = search_dist * 5

    # all object labels higher than background
    unique_objects_id = np.unique(object_masks)[np.unique(object_masks)>0]
    
    # if has one candiadte object (currently requires dna to always have one)
    if len(unique_objects_id) >0:

        for i in unique_objects_id:
            cand_object = object_masks == i
            cand_object[cand_object>0]=1
            cand_object = np.array(cand_object)
        
            # calculate candiate object distance to the input coord (eg., from prior timepoint)
            region = skimage.measure.regionprops (skimage.measure.label(cand_object))[0]   
            _dist = round(np.linalg.norm(np.array([region.centroid[1], region.centroid[0]])
                                                    - np.array(object_centroid)))
            
             # use area
            if use_area and abs(region.area - object_area)/object_area <=0.4:
                # also use reference distance
                if len(ref_centroid) == 2:
                    _dist_ref = round(np.linalg.norm(np.array([region.centroid[1], region.centroid[0]])
                                                    - np.array(ref_centroid)))
                
                    if _dist_ref + _dist  <= combined_dist:
                        combined_dist = _dist_ref + _dist
                        kept_object = cand_object
                        
                # not using reference distance        
                else:
                    if _dist <= found_dist:  
                        found_dist = _dist
                        kept_object = cand_object   
                        
            # if not use area or area changes too variable
            else: 
                # also use reference distance
                if len(ref_centroid) == 2:
                    _dist_ref = round(np.linalg.norm(np.array([region.centroid[1], region.centroid[0]])
                                                    - np.array(ref_centroid)))
                
                    if _dist_ref + _dist  <= combined_dist:
                        combined_dist = _dist_ref + _dist
                        kept_object = cand_object
                        
                # not using reference distance                
                else:
                    if _dist <= found_dist:  
                        found_dist = _dist
                        kept_object = cand_object
        
        # if use pre-defined object mask
        if len(saved_object_mask)>0 and saved_object_mask.shape == image_ch.shape:
            kept_object = saved_object_mask
            region = skimage.measure.regionprops (skimage.measure.label(kept_object))[0]    
            found_object_centroid = [round(region.centroid[1]), round(region.centroid[0])]
            found_object_area = region.area
            found_dist = search_dist
            
        # if there is one object passing the qualification                
        elif len(kept_object) > 0:                
            region = skimage.measure.regionprops (skimage.measure.label(kept_object))[0]    
            found_object_centroid = [round(region.centroid[1]), round(region.centroid[0])]
            found_object_area = region.area

        # if no valid objects, append empty masks and return input coord (e.g., from last timepoint)
        else:
            kept_object = np.zeros(image_ch[z_selected].shape) 
            #  this results in ms2 acumulation qualitative mode
        
            found_object_centroid = object_centroid  # use prior centroid if there is transient loss
            found_object_area = object_area
            found_dist = search_dist
            
            
        
    else: # if no candiadte object for lac: eg., lac loci lost
        kept_object = np.zeros(image_ch[z_selected].shape) 
        #  this results in ms2 acumulation qualitative mode
        
        found_object_centroid = object_centroid  # use prior centroid if there is transient loss
        found_object_area = object_area
        found_dist = search_dist
        
    # return [object mask, object centroid, object area, and the min distance] 
    return [kept_object, found_object_centroid, found_object_area, found_dist]

# %% [markdown]
# ### 2. Run analysis for the cell

# %%
# initiate measurement dict
all_measurement_timed = {}

# loop through all timepoints
for timepoint in _all_time_points[:]:
    
    # if timepoints annotaed
    if (timepoint +1) in annotated_timepoints.keys():
        
        # if cell centroid is not np.nan, use annotated cell centroid
        if annotated_timepoints[(timepoint +1)]['cell_centroid'][0]>0:
            cell_centroid = annotated_timepoints[(timepoint +1)]['cell_centroid']
            cell_centroid = [int(_coord) for _coord in cell_centroid]
        # or use prior timepoint info
        else:
            cell_centroid= cell_object_info[1]
            
        # if foci centroid is not np.nan, use annotated foci centroid
        if annotated_timepoints[(timepoint +1)]['foci_centroid'][0]>0:
            foci_centroid = annotated_timepoints[(timepoint +1)]['foci_centroid']
            foci_centroid = [int(_coord) for _coord in foci_centroid]
        # or use prior timepoint info
        else:
            foci_centroid = foci_object_info[1]
            
        
        # if area is not np.nan, use annotated cell area
        if annotated_timepoints[(timepoint +1)]['cell_area']>0:
            cell_area = annotated_timepoints[(timepoint +1)]['cell_area']
        # or use prior timepoint info
        else:
            cell_area =cell_object_info[2]
            
    # if timepoints NOT annotaed, use prior timepoint info
    else:
        cell_centroid= cell_object_info[1]
        cell_area =cell_object_info[2]
        foci_centroid = foci_object_info[1]
            
          
    print (f'-- tracking cell at timepoint {timepoint}.') 
    print ('++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++')
    
    # track and locate cell of interest
    cell_object_info = segment_and_track_object(images, 1,
                                                time = timepoint, 
                                                object_centroid=cell_centroid,
                                                object_area =cell_area, mode ='nuclei',
                                                z_selected = z_selected,
                                               crop_x1=crop_x1,crop_x2=crop_x2,crop_y1=crop_y1,crop_y2=crop_y2)
    
    
    # if foci centorid is anntoated for THIS timepoint, just use the foci centroid for foci tracking
    if (timepoint +1) in annotated_timepoints.keys() and annotated_timepoints[(timepoint +1)]['foci_centroid'][0]>0:
        ref_centroid = []
    # otherwise, use the found cell centroid as ref centroid to assist foci tracking;
    # where both the found cell centroid and the prior foci centorid are considered
    else:    
        ref_centroid = cell_object_info[1]
    
    
    if np.sum(cell_object_info[0]) > 600 and use_STD_foci_segmentation:
        foci_segmentation = 'STD'
    else:
        foci_segmentation = 'Yen'

    # track and locate foci of interest
    foci_object_info = segment_and_track_object(images, 2,
                                                time = timepoint, 
                                                object_centroid=foci_centroid, ref_centroid = ref_centroid,
                                                foci_segmentation = foci_segmentation, cell_mask = cell_object_info[0],
                                                object_area =[], mode ='foci', foci_filter= foci_filter,
                                                z_selected = z_selected,
                                                crop_x1=crop_x1,crop_x2=crop_x2,crop_y1=crop_y1,crop_y2=crop_y2)
    
    # load raw image for each channel
    im_dna = np.array(images.get_frame_2D (v=timepoint, c=0, z=z_selected))[crop_y1: crop_y2, crop_x1: crop_x2]
    im_lac = np.array(images.get_frame_2D (v=timepoint, c=1, z=z_selected))[crop_y1: crop_y2, crop_x1: crop_x2]
    im_ms = np.array(images.get_frame_2D (v=timepoint, c=2, z=z_selected))[crop_y1: crop_y2, crop_x1: crop_x2]
    
    # get noncell backgroud using Li
    all_dna_mask = dilation(im_dna>threshold_li(im_dna), disk(10))
    noncell_background = all_dna_mask == 0
    #####################################
    # measure average intensity, etc
    
    # initiate _save_mask
    _save_mask = False
    
    # append 'mitosis' for timepoints relevant
    if timepoint in _mitosis_duration:
        all_measurement_timed[str(timepoint+1)] = 'mitosis'
    
    # if a valid foci can be found before or after, measure and save masks
    elif (timepoint in _first_duration and np.sum(foci_object_info[0] ) > 0 or
         timepoint in _second_duration and np.sum(cell_object_info[0] * foci_object_info[0]) > 0):
        
        foci_mask_to_measure = dilation (foci_object_info[0],disk(_foci_measure_size))
        cell_mask_to_measure = cell_object_info[0] * (foci_mask_to_measure==0)
    
        ave_ms_noncell_background = np.mean((noncell_background * im_ms)[noncell_background!=0])
    
        ave_ms_foci = np.mean((foci_mask_to_measure * im_ms)[foci_mask_to_measure!=0])
        ave_ms_foci= ave_ms_foci - ave_ms_noncell_background
    
        ave_ms_cell = np.mean((cell_mask_to_measure * im_ms)[cell_mask_to_measure!=0])
        ave_ms_cell= ave_ms_cell - ave_ms_noncell_background
    
        norm_ave_ms_foci = ave_ms_foci/ave_ms_cell
        print(f'-- normalized foci intensity for ms2 is {norm_ave_ms_foci}')
    
        all_measurement_timed[str(timepoint+1)] = norm_ave_ms_foci
        
        _save_mask = True
    
    # if no valid foci can be found (after incorporation), determine if there is ms2 foci qualitatively 
    else:
        # if no lac foci, check if there is ms2 foci
        ms_intensity = dilation(cell_object_info[0]) * im_ms
        ms_intensity_filtered = ms_intensity[ms_intensity!=0]
        ms_positive_th =np.mean(ms_intensity_filtered) + np.std(ms_intensity_filtered)*3

        ms_mask = (im_ms > ms_positive_th)*cell_object_info[0]
        ms_mask = dilation(ms_mask)
        ms_mask = remove_small_objects(ms_mask, foci_filter+5)
        
        _save_mask = True
        foci_object_info[0] =  ms_mask

        if np.sum(ms_mask) >foci_filter:
            
            if np.sum(cell_object_info[0]) > nuclei_filter:
                foci_mask_to_measure = ms_mask
                cell_mask_to_measure = cell_object_info[0] * (foci_mask_to_measure==0)
                
                ave_ms_noncell_background = np.mean((noncell_background * im_ms)[noncell_background!=0])
            
                ave_ms_foci = np.mean((foci_mask_to_measure * im_ms)[foci_mask_to_measure!=0])
                ave_ms_foci= ave_ms_foci - ave_ms_noncell_background
                
                ave_ms_cell = np.mean((cell_mask_to_measure * im_ms)[cell_mask_to_measure!=0])
                ave_ms_cell= ave_ms_cell - ave_ms_noncell_background
    
                norm_ave_ms_foci = ave_ms_foci/ave_ms_cell
        
                print(f'-- normalized foci intensity for ms2 is {norm_ave_ms_foci}')
                all_measurement_timed[str(timepoint+1)] = f'yes_{norm_ave_ms_foci}'
                
            else:
                all_measurement_timed[str(timepoint+1)] = 'yes'

        else:
            all_measurement_timed[str(timepoint+1)] = 'no'
        

    #####################################
    # save masks and cropped images for the timepoints where cell and lac foci can be found
    data_cell_path = data_main_folder + os.sep + f'mask_{cell_name}'
    if not os.path.exists(data_cell_path):
        os.mkdir(data_cell_path)
    
    if _save_mask:
        mask_savename_list = [data_cell_path + os.sep + f'Pos11_DNA_t{timepoint+1}.tif',
                 #data_cell_path + os.sep + f'Pos11_DNA_raw_t{timepoint+1}.tif', 
                   data_cell_path + os.sep + f'Pos11_Lac_t{timepoint+1}.tif',
                 #data_cell_path + os.sep + f'Pos11_Lac_raw_t{timepoint+1}.tif'
                         ]
    
        im_to_save = [cell_object_info[0],
                  #im_dna,
                  foci_object_info[0],
                  #im_lac
                 ]
                  
        for _im, _name in zip(im_to_save, mask_savename_list):
        #if not os.path.exists(_name):
            #os.mkdirs()
            if os.path.exists(_name):
                os.remove(_name)
            io.imsave(_name, _im, check_contrast=False)
# Out:
# -- tracking cell at timepoint 0.
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# >>>> using CPU
# Running test snippet to check if MKL-DNN working
# see https://pytorch.org/docs/stable/backends.html?highlight=mkl
# ** MKL version working - CPU version is sped up. **
# processing 1 image(s)
# time spent: running network 1.92s; flow+mask computation 0.19
# estimated masks for 1 image(s) in 2.13 sec
# >>>> TOTAL TIME 2.13 sec
# C:\Users\Shiwei\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:81: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
# -- normalized foci intensity for ms2 is 0.8271187096477224
# -- tracking cell at timepoint 1.
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# C:\Users\Shiwei\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:180: UserWarning: D:\Analyzed_CellBio\Stam\Lac_Ms_live\210914_263_pos19\mask_control_1\Pos11_DNA_t1.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# C:\Users\Shiwei\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:180: UserWarning: D:\Analyzed_CellBio\Stam\Lac_Ms_live\210914_263_pos19\mask_control_1\Pos11_Lac_t1.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# >>>> using CPU
# Running test snippet to check if MKL-DNN working
# see https://pytorch.org/docs/stable/backends.html?highlight=mkl
# ** MKL version working - CPU version is sped up. **
# processing 1 image(s)
# time spent: running network 1.50s; flow+mask computation 0.24
# estimated masks for 1 image(s) in 1.76 sec
# >>>> TOTAL TIME 1.76 sec
# -- normalized foci intensity for ms2 is 0.882082720947351
# -- tracking cell at timepoint 2.
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# C:\Users\Shiwei\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:180: UserWarning: D:\Analyzed_CellBio\Stam\Lac_Ms_live\210914_263_pos19\mask_control_1\Pos11_DNA_t2.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# C:\Users\Shiwei\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:180: UserWarning: D:\Analyzed_CellBio\Stam\Lac_Ms_live\210914_263_pos19\mask_control_1\Pos11_Lac_t2.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# >>>> using CPU
# Running test snippet to check if MKL-DNN working
# see https://pytorch.org/docs/stable/backends.html?highlight=mkl
# ** MKL version working - CPU version is sped up. **
# processing 1 image(s)
# time spent: running network 1.50s; flow+mask computation 0.17
# estimated masks for 1 image(s) in 1.70 sec
# >>>> TOTAL TIME 1.70 sec
# -- normalized foci intensity for ms2 is 1.547982965380798
# -- tracking cell at timepoint 3.
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# C:\Users\Shiwei\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:180: UserWarning: D:\Analyzed_CellBio\Stam\Lac_Ms_live\210914_263_pos19\mask_control_1\Pos11_DNA_t3.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# C:\Users\Shiwei\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:180: UserWarning: D:\Analyzed_CellBio\Stam\Lac_Ms_live\210914_263_pos19\mask_control_1\Pos11_Lac_t3.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# >>>> using CPU
# Running test snippet to check if MKL-DNN working
# see https://pytorch.org/docs/stable/backends.html?highlight=mkl
# ** MKL version working - CPU version is sped up. **
# processing 1 image(s)
# time spent: running network 1.51s; flow+mask computation 0.23
# estimated masks for 1 image(s) in 1.76 sec
# >>>> TOTAL TIME 1.76 sec
# -- normalized foci intensity for ms2 is 0.6787546028525607
# -- tracking cell at timepoint 4.
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# C:\Users\Shiwei\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:180: UserWarning: D:\Analyzed_CellBio\Stam\Lac_Ms_live\210914_263_pos19\mask_control_1\Pos11_DNA_t4.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# C:\Users\Shiwei\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:180: UserWarning: D:\Analyzed_CellBio\Stam\Lac_Ms_live\210914_263_pos19\mask_control_1\Pos11_Lac_t4.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# >>>> using CPU
# Running test snippet to check if MKL-DNN working
# see https://pytorch.org/docs/stable/backends.html?highlight=mkl
# ** MKL version working - CPU version is sped up. **
# processing 1 image(s)
# time spent: running network 1.45s; flow+mask computation 0.17
# estimated masks for 1 image(s) in 1.65 sec
# >>>> TOTAL TIME 1.65 sec
# -- normalized foci intensity for ms2 is 1.260548481792696
# -- tracking cell at timepoint 5.
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# C:\Users\Shiwei\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:180: UserWarning: D:\Analyzed_CellBio\Stam\Lac_Ms_live\210914_263_pos19\mask_control_1\Pos11_DNA_t5.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# C:\Users\Shiwei\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:180: UserWarning: D:\Analyzed_CellBio\Stam\Lac_Ms_live\210914_263_pos19\mask_control_1\Pos11_Lac_t5.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# >>>> using CPU
# Running test snippet to check if MKL-DNN working
# see https://pytorch.org/docs/stable/backends.html?highlight=mkl
# ** MKL version working - CPU version is sped up. **
# processing 1 image(s)
# time spent: running network 1.64s; flow+mask computation 0.19
# estimated masks for 1 image(s) in 1.85 sec
# >>>> TOTAL TIME 1.85 sec
# -- normalized foci intensity for ms2 is 1.0476028617482258
# -- tracking cell at timepoint 6.
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# >>>> using CPU
# Running test snippet to check if MKL-DNN working
# see https://pytorch.org/docs/stable/backends.html?highlight=mkl
# ** MKL version working - CPU version is sped up. **
# C:\Users\Shiwei\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:180: UserWarning: D:\Analyzed_CellBio\Stam\Lac_Ms_live\210914_263_pos19\mask_control_1\Pos11_DNA_t6.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# C:\Users\Shiwei\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:180: UserWarning: D:\Analyzed_CellBio\Stam\Lac_Ms_live\210914_263_pos19\mask_control_1\Pos11_Lac_t6.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# processing 1 image(s)
# time spent: running network 1.56s; flow+mask computation 0.24
# estimated masks for 1 image(s) in 1.83 sec
# >>>> TOTAL TIME 1.83 sec
# -- normalized foci intensity for ms2 is 1.1792149152896518
# -- tracking cell at timepoint 7.
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# >>>> using CPU
# Running test snippet to check if MKL-DNN working
# see https://pytorch.org/docs/stable/backends.html?highlight=mkl
# ** MKL version working - CPU version is sped up. **
# C:\Users\Shiwei\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:180: UserWarning: D:\Analyzed_CellBio\Stam\Lac_Ms_live\210914_263_pos19\mask_control_1\Pos11_DNA_t7.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# C:\Users\Shiwei\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:180: UserWarning: D:\Analyzed_CellBio\Stam\Lac_Ms_live\210914_263_pos19\mask_control_1\Pos11_Lac_t7.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# processing 1 image(s)
# time spent: running network 1.51s; flow+mask computation 0.19
# estimated masks for 1 image(s) in 1.72 sec
# >>>> TOTAL TIME 1.72 sec
# -- normalized foci intensity for ms2 is 1.2411936243537856
# -- tracking cell at timepoint 8.
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# C:\Users\Shiwei\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:180: UserWarning: D:\Analyzed_CellBio\Stam\Lac_Ms_live\210914_263_pos19\mask_control_1\Pos11_DNA_t8.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# C:\Users\Shiwei\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:180: UserWarning: D:\Analyzed_CellBio\Stam\Lac_Ms_live\210914_263_pos19\mask_control_1\Pos11_Lac_t8.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# >>>> using CPU
# Running test snippet to check if MKL-DNN working
# see https://pytorch.org/docs/stable/backends.html?highlight=mkl
# ** MKL version working - CPU version is sped up. **
# processing 1 image(s)
# time spent: running network 1.58s; flow+mask computation 0.23
# estimated masks for 1 image(s) in 1.84 sec
# >>>> TOTAL TIME 1.84 sec
# -- normalized foci intensity for ms2 is 1.4553126126697804
# -- tracking cell at timepoint 9.
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# >>>> using CPU
# Running test snippet to check if MKL-DNN working
# see https://pytorch.org/docs/stable/backends.html?highlight=mkl
# ** MKL version working - CPU version is sped up. **
# C:\Users\Shiwei\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:180: UserWarning: D:\Analyzed_CellBio\Stam\Lac_Ms_live\210914_263_pos19\mask_control_1\Pos11_DNA_t9.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# C:\Users\Shiwei\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:180: UserWarning: D:\Analyzed_CellBio\Stam\Lac_Ms_live\210914_263_pos19\mask_control_1\Pos11_Lac_t9.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# processing 1 image(s)
# time spent: running network 1.37s; flow+mask computation 0.18
# estimated masks for 1 image(s) in 1.58 sec
# >>>> TOTAL TIME 1.58 sec
# -- normalized foci intensity for ms2 is 0.9250779527228135
# -- tracking cell at timepoint 10.
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# C:\Users\Shiwei\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:180: UserWarning: D:\Analyzed_CellBio\Stam\Lac_Ms_live\210914_263_pos19\mask_control_1\Pos11_DNA_t10.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# C:\Users\Shiwei\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:180: UserWarning: D:\Analyzed_CellBio\Stam\Lac_Ms_live\210914_263_pos19\mask_control_1\Pos11_Lac_t10.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# >>>> using CPU
# Running test snippet to check if MKL-DNN working
# see https://pytorch.org/docs/stable/backends.html?highlight=mkl
# ** MKL version working - CPU version is sped up. **
# processing 1 image(s)
# time spent: running network 1.62s; flow+mask computation 0.19
# estimated masks for 1 image(s) in 1.82 sec
# >>>> TOTAL TIME 1.82 sec
# -- normalized foci intensity for ms2 is 1.3219570367787157
# -- tracking cell at timepoint 11.
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# >>>> using CPU
# Running test snippet to check if MKL-DNN working
# see https://pytorch.org/docs/stable/backends.html?highlight=mkl
# ** MKL version working - CPU version is sped up. **
# C:\Users\Shiwei\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:180: UserWarning: D:\Analyzed_CellBio\Stam\Lac_Ms_live\210914_263_pos19\mask_control_1\Pos11_DNA_t11.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# C:\Users\Shiwei\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:180: UserWarning: D:\Analyzed_CellBio\Stam\Lac_Ms_live\210914_263_pos19\mask_control_1\Pos11_Lac_t11.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# processing 1 image(s)
# time spent: running network 1.36s; flow+mask computation 0.23
# estimated masks for 1 image(s) in 1.61 sec
# >>>> TOTAL TIME 1.61 sec
# -- normalized foci intensity for ms2 is 0.6671297940470802
# -- tracking cell at timepoint 12.
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# C:\Users\Shiwei\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:180: UserWarning: D:\Analyzed_CellBio\Stam\Lac_Ms_live\210914_263_pos19\mask_control_1\Pos11_DNA_t12.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# C:\Users\Shiwei\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:180: UserWarning: D:\Analyzed_CellBio\Stam\Lac_Ms_live\210914_263_pos19\mask_control_1\Pos11_Lac_t12.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# >>>> using CPU
# Running test snippet to check if MKL-DNN working
# see https://pytorch.org/docs/stable/backends.html?highlight=mkl
# ** MKL version working - CPU version is sped up. **
# processing 1 image(s)
# time spent: running network 1.59s; flow+mask computation 0.18
# estimated masks for 1 image(s) in 1.79 sec
# >>>> TOTAL TIME 1.79 sec
# -- normalized foci intensity for ms2 is 0.8335236316546151
# -- tracking cell at timepoint 13.
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# >>>> using CPU
# Running test snippet to check if MKL-DNN working
# see https://pytorch.org/docs/stable/backends.html?highlight=mkl
# ** MKL version working - CPU version is sped up. **
# C:\Users\Shiwei\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:180: UserWarning: D:\Analyzed_CellBio\Stam\Lac_Ms_live\210914_263_pos19\mask_control_1\Pos11_DNA_t13.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# C:\Users\Shiwei\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:180: UserWarning: D:\Analyzed_CellBio\Stam\Lac_Ms_live\210914_263_pos19\mask_control_1\Pos11_Lac_t13.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# processing 1 image(s)
# time spent: running network 1.45s; flow+mask computation 0.22
# estimated masks for 1 image(s) in 1.69 sec
# >>>> TOTAL TIME 1.69 sec
# -- normalized foci intensity for ms2 is 1.0322009316733534
# -- tracking cell at timepoint 14.
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# C:\Users\Shiwei\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:180: UserWarning: D:\Analyzed_CellBio\Stam\Lac_Ms_live\210914_263_pos19\mask_control_1\Pos11_DNA_t14.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# C:\Users\Shiwei\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:180: UserWarning: D:\Analyzed_CellBio\Stam\Lac_Ms_live\210914_263_pos19\mask_control_1\Pos11_Lac_t14.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# >>>> using CPU
# Running test snippet to check if MKL-DNN working
# see https://pytorch.org/docs/stable/backends.html?highlight=mkl
# ** MKL version working - CPU version is sped up. **
# processing 1 image(s)
# time spent: running network 1.39s; flow+mask computation 0.18
# estimated masks for 1 image(s) in 1.58 sec
# >>>> TOTAL TIME 1.58 sec
# -- normalized foci intensity for ms2 is 0.5889254945528934
# -- tracking cell at timepoint 15.
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# C:\Users\Shiwei\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:180: UserWarning: D:\Analyzed_CellBio\Stam\Lac_Ms_live\210914_263_pos19\mask_control_1\Pos11_DNA_t15.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# C:\Users\Shiwei\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:180: UserWarning: D:\Analyzed_CellBio\Stam\Lac_Ms_live\210914_263_pos19\mask_control_1\Pos11_Lac_t15.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# >>>> using CPU
# Running test snippet to check if MKL-DNN working
# see https://pytorch.org/docs/stable/backends.html?highlight=mkl
# ** MKL version working - CPU version is sped up. **
# processing 1 image(s)
# time spent: running network 1.28s; flow+mask computation 0.15
# estimated masks for 1 image(s) in 1.46 sec
# >>>> TOTAL TIME 1.46 sec
# -- normalized foci intensity for ms2 is 0.6193430558351064
# -- tracking cell at timepoint 16.
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# >>>> using CPU
# C:\Users\Shiwei\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:180: UserWarning: D:\Analyzed_CellBio\Stam\Lac_Ms_live\210914_263_pos19\mask_control_1\Pos11_DNA_t16.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# C:\Users\Shiwei\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:180: UserWarning: D:\Analyzed_CellBio\Stam\Lac_Ms_live\210914_263_pos19\mask_control_1\Pos11_Lac_t16.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# Running test snippet to check if MKL-DNN working
# see https://pytorch.org/docs/stable/backends.html?highlight=mkl
# ** MKL version working - CPU version is sped up. **
# processing 1 image(s)
# time spent: running network 1.36s; flow+mask computation 0.15
# estimated masks for 1 image(s) in 1.53 sec
# >>>> TOTAL TIME 1.53 sec
# -- normalized foci intensity for ms2 is 0.9974520961667269
# -- tracking cell at timepoint 17.
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# C:\Users\Shiwei\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:180: UserWarning: D:\Analyzed_CellBio\Stam\Lac_Ms_live\210914_263_pos19\mask_control_1\Pos11_DNA_t17.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# C:\Users\Shiwei\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:180: UserWarning: D:\Analyzed_CellBio\Stam\Lac_Ms_live\210914_263_pos19\mask_control_1\Pos11_Lac_t17.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# >>>> using CPU
# Running test snippet to check if MKL-DNN working
# see https://pytorch.org/docs/stable/backends.html?highlight=mkl
# ** MKL version working - CPU version is sped up. **
# processing 1 image(s)
# time spent: running network 1.36s; flow+mask computation 0.12
# estimated masks for 1 image(s) in 1.50 sec
# >>>> TOTAL TIME 1.50 sec
# -- normalized foci intensity for ms2 is 0.9378283175369081
# -- tracking cell at timepoint 18.
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# C:\Users\Shiwei\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:180: UserWarning: D:\Analyzed_CellBio\Stam\Lac_Ms_live\210914_263_pos19\mask_control_1\Pos11_DNA_t18.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# C:\Users\Shiwei\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:180: UserWarning: D:\Analyzed_CellBio\Stam\Lac_Ms_live\210914_263_pos19\mask_control_1\Pos11_Lac_t18.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# >>>> using CPU
# Running test snippet to check if MKL-DNN working
# see https://pytorch.org/docs/stable/backends.html?highlight=mkl
# ** MKL version working - CPU version is sped up. **
# processing 1 image(s)
# time spent: running network 1.47s; flow+mask computation 0.11
# estimated masks for 1 image(s) in 1.61 sec
# >>>> TOTAL TIME 1.61 sec
# -- normalized foci intensity for ms2 is 1.0241213175111312
# -- tracking cell at timepoint 19.
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# C:\Users\Shiwei\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:180: UserWarning: D:\Analyzed_CellBio\Stam\Lac_Ms_live\210914_263_pos19\mask_control_1\Pos11_DNA_t19.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# C:\Users\Shiwei\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:180: UserWarning: D:\Analyzed_CellBio\Stam\Lac_Ms_live\210914_263_pos19\mask_control_1\Pos11_Lac_t19.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# >>>> using CPU
# Running test snippet to check if MKL-DNN working
# see https://pytorch.org/docs/stable/backends.html?highlight=mkl
# ** MKL version working - CPU version is sped up. **
# processing 1 image(s)
# time spent: running network 1.36s; flow+mask computation 0.16
# estimated masks for 1 image(s) in 1.54 sec
# >>>> TOTAL TIME 1.54 sec
# -- normalized foci intensity for ms2 is 0.6760178741917963
# -- tracking cell at timepoint 20.
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# >>>> using CPU
# Running test snippet to check if MKL-DNN working
# see https://pytorch.org/docs/stable/backends.html?highlight=mkl
# ** MKL version working - CPU version is sped up. **
# C:\Users\Shiwei\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:180: UserWarning: D:\Analyzed_CellBio\Stam\Lac_Ms_live\210914_263_pos19\mask_control_1\Pos11_DNA_t20.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# C:\Users\Shiwei\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:180: UserWarning: D:\Analyzed_CellBio\Stam\Lac_Ms_live\210914_263_pos19\mask_control_1\Pos11_Lac_t20.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# processing 1 image(s)
# time spent: running network 1.38s; flow+mask computation 0.16
# estimated masks for 1 image(s) in 1.56 sec
# >>>> TOTAL TIME 1.56 sec
# -- normalized foci intensity for ms2 is 1.1219924041275662
# -- tracking cell at timepoint 21.
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# C:\Users\Shiwei\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:180: UserWarning: D:\Analyzed_CellBio\Stam\Lac_Ms_live\210914_263_pos19\mask_control_1\Pos11_DNA_t21.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# C:\Users\Shiwei\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:180: UserWarning: D:\Analyzed_CellBio\Stam\Lac_Ms_live\210914_263_pos19\mask_control_1\Pos11_Lac_t21.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# >>>> using CPU
# Running test snippet to check if MKL-DNN working
# see https://pytorch.org/docs/stable/backends.html?highlight=mkl
# ** MKL version working - CPU version is sped up. **
# processing 1 image(s)
# time spent: running network 1.35s; flow+mask computation 0.17
# estimated masks for 1 image(s) in 1.54 sec
# >>>> TOTAL TIME 1.54 sec
# -- normalized foci intensity for ms2 is 1.1931232278302855
# -- tracking cell at timepoint 22.
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# C:\Users\Shiwei\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:180: UserWarning: D:\Analyzed_CellBio\Stam\Lac_Ms_live\210914_263_pos19\mask_control_1\Pos11_DNA_t22.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# C:\Users\Shiwei\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:180: UserWarning: D:\Analyzed_CellBio\Stam\Lac_Ms_live\210914_263_pos19\mask_control_1\Pos11_Lac_t22.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# >>>> using CPU
# Running test snippet to check if MKL-DNN working
# see https://pytorch.org/docs/stable/backends.html?highlight=mkl
# ** MKL version working - CPU version is sped up. **
# processing 1 image(s)
# time spent: running network 1.31s; flow+mask computation 0.17
# estimated masks for 1 image(s) in 1.51 sec
# >>>> TOTAL TIME 1.51 sec
# -- normalized foci intensity for ms2 is 1.2906974067766521
# -- tracking cell at timepoint 23.
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# >>>> using CPU
# Running test snippet to check if MKL-DNN working
# see https://pytorch.org/docs/stable/backends.html?highlight=mkl
# ** MKL version working - CPU version is sped up. **
# C:\Users\Shiwei\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:180: UserWarning: D:\Analyzed_CellBio\Stam\Lac_Ms_live\210914_263_pos19\mask_control_1\Pos11_DNA_t23.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# C:\Users\Shiwei\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:180: UserWarning: D:\Analyzed_CellBio\Stam\Lac_Ms_live\210914_263_pos19\mask_control_1\Pos11_Lac_t23.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# processing 1 image(s)
# time spent: running network 1.31s; flow+mask computation 0.15
# estimated masks for 1 image(s) in 1.48 sec
# >>>> TOTAL TIME 1.48 sec
# -- normalized foci intensity for ms2 is 1.3012703331990023
# -- tracking cell at timepoint 24.
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# >>>> using CPU
# Running test snippet to check if MKL-DNN working
# see https://pytorch.org/docs/stable/backends.html?highlight=mkl
# ** MKL version working - CPU version is sped up. **
# C:\Users\Shiwei\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:180: UserWarning: D:\Analyzed_CellBio\Stam\Lac_Ms_live\210914_263_pos19\mask_control_1\Pos11_DNA_t24.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# C:\Users\Shiwei\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:180: UserWarning: D:\Analyzed_CellBio\Stam\Lac_Ms_live\210914_263_pos19\mask_control_1\Pos11_Lac_t24.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# processing 1 image(s)
# time spent: running network 1.47s; flow+mask computation 0.20
# estimated masks for 1 image(s) in 1.69 sec
# >>>> TOTAL TIME 1.69 sec
# -- normalized foci intensity for ms2 is 1.187176695053942
# -- tracking cell at timepoint 25.
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# C:\Users\Shiwei\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:180: UserWarning: D:\Analyzed_CellBio\Stam\Lac_Ms_live\210914_263_pos19\mask_control_1\Pos11_DNA_t25.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# C:\Users\Shiwei\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:180: UserWarning: D:\Analyzed_CellBio\Stam\Lac_Ms_live\210914_263_pos19\mask_control_1\Pos11_Lac_t25.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# >>>> using CPU
# Running test snippet to check if MKL-DNN working
# see https://pytorch.org/docs/stable/backends.html?highlight=mkl
# ** MKL version working - CPU version is sped up. **
# processing 1 image(s)
# time spent: running network 1.31s; flow+mask computation 0.19
# estimated masks for 1 image(s) in 1.52 sec
# >>>> TOTAL TIME 1.52 sec
# -- normalized foci intensity for ms2 is 0.849564328621526
# -- tracking cell at timepoint 26.
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# >>>> using CPU
# Running test snippet to check if MKL-DNN working
# see https://pytorch.org/docs/stable/backends.html?highlight=mkl
# ** MKL version working - CPU version is sped up. **
# C:\Users\Shiwei\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:180: UserWarning: D:\Analyzed_CellBio\Stam\Lac_Ms_live\210914_263_pos19\mask_control_1\Pos11_DNA_t26.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# C:\Users\Shiwei\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:180: UserWarning: D:\Analyzed_CellBio\Stam\Lac_Ms_live\210914_263_pos19\mask_control_1\Pos11_Lac_t26.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# processing 1 image(s)
# time spent: running network 1.33s; flow+mask computation 0.22
# estimated masks for 1 image(s) in 1.56 sec
# >>>> TOTAL TIME 1.56 sec
# -- normalized foci intensity for ms2 is 1.076283279237172
# -- tracking cell at timepoint 27.
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# >>>> using CPU
# Running test snippet to check if MKL-DNN working
# see https://pytorch.org/docs/stable/backends.html?highlight=mkl
# ** MKL version working - CPU version is sped up. **
# C:\Users\Shiwei\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:180: UserWarning: D:\Analyzed_CellBio\Stam\Lac_Ms_live\210914_263_pos19\mask_control_1\Pos11_DNA_t27.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# C:\Users\Shiwei\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:180: UserWarning: D:\Analyzed_CellBio\Stam\Lac_Ms_live\210914_263_pos19\mask_control_1\Pos11_Lac_t27.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# processing 1 image(s)
# time spent: running network 1.34s; flow+mask computation 0.20
# estimated masks for 1 image(s) in 1.56 sec
# >>>> TOTAL TIME 1.57 sec
# -- normalized foci intensity for ms2 is 1.1445805834332479
# -- tracking cell at timepoint 28.
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# C:\Users\Shiwei\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:180: UserWarning: D:\Analyzed_CellBio\Stam\Lac_Ms_live\210914_263_pos19\mask_control_1\Pos11_DNA_t28.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# C:\Users\Shiwei\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:180: UserWarning: D:\Analyzed_CellBio\Stam\Lac_Ms_live\210914_263_pos19\mask_control_1\Pos11_Lac_t28.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# >>>> using CPU
# Running test snippet to check if MKL-DNN working
# see https://pytorch.org/docs/stable/backends.html?highlight=mkl
# ** MKL version working - CPU version is sped up. **
# processing 1 image(s)
# time spent: running network 1.27s; flow+mask computation 0.18
# estimated masks for 1 image(s) in 1.47 sec
# >>>> TOTAL TIME 1.47 sec
# -- normalized foci intensity for ms2 is 1.099687122159843
# -- tracking cell at timepoint 29.
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# >>>> using CPU
# Running test snippet to check if MKL-DNN working
# see https://pytorch.org/docs/stable/backends.html?highlight=mkl
# ** MKL version working - CPU version is sped up. **
# C:\Users\Shiwei\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:180: UserWarning: D:\Analyzed_CellBio\Stam\Lac_Ms_live\210914_263_pos19\mask_control_1\Pos11_DNA_t29.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# C:\Users\Shiwei\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:180: UserWarning: D:\Analyzed_CellBio\Stam\Lac_Ms_live\210914_263_pos19\mask_control_1\Pos11_Lac_t29.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# processing 1 image(s)
# time spent: running network 1.46s; flow+mask computation 0.18
# estimated masks for 1 image(s) in 1.66 sec
# >>>> TOTAL TIME 1.66 sec
# -- normalized foci intensity for ms2 is 0.5009958929864152
# -- tracking cell at timepoint 30.
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# C:\Users\Shiwei\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:180: UserWarning: D:\Analyzed_CellBio\Stam\Lac_Ms_live\210914_263_pos19\mask_control_1\Pos11_DNA_t30.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# C:\Users\Shiwei\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:180: UserWarning: D:\Analyzed_CellBio\Stam\Lac_Ms_live\210914_263_pos19\mask_control_1\Pos11_Lac_t30.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# >>>> using CPU
# Running test snippet to check if MKL-DNN working
# see https://pytorch.org/docs/stable/backends.html?highlight=mkl
# ** MKL version working - CPU version is sped up. **
# processing 1 image(s)
# time spent: running network 1.28s; flow+mask computation 0.22
# estimated masks for 1 image(s) in 1.52 sec
# >>>> TOTAL TIME 1.52 sec
# -- normalized foci intensity for ms2 is 0.9614136428744001
# -- tracking cell at timepoint 31.
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# >>>> using CPU
# Running test snippet to check if MKL-DNN working
# see https://pytorch.org/docs/stable/backends.html?highlight=mkl
# ** MKL version working - CPU version is sped up. **
# C:\Users\Shiwei\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:180: UserWarning: D:\Analyzed_CellBio\Stam\Lac_Ms_live\210914_263_pos19\mask_control_1\Pos11_DNA_t31.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# C:\Users\Shiwei\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:180: UserWarning: D:\Analyzed_CellBio\Stam\Lac_Ms_live\210914_263_pos19\mask_control_1\Pos11_Lac_t31.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# processing 1 image(s)
# time spent: running network 1.40s; flow+mask computation 0.22
# estimated masks for 1 image(s) in 1.64 sec
# >>>> TOTAL TIME 1.64 sec
# -- normalized foci intensity for ms2 is 0.9421695544671447
# -- tracking cell at timepoint 32.
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# C:\Users\Shiwei\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:180: UserWarning: D:\Analyzed_CellBio\Stam\Lac_Ms_live\210914_263_pos19\mask_control_1\Pos11_DNA_t32.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# C:\Users\Shiwei\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:180: UserWarning: D:\Analyzed_CellBio\Stam\Lac_Ms_live\210914_263_pos19\mask_control_1\Pos11_Lac_t32.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# >>>> using CPU
# Running test snippet to check if MKL-DNN working
# see https://pytorch.org/docs/stable/backends.html?highlight=mkl
# ** MKL version working - CPU version is sped up. **
# processing 1 image(s)
# time spent: running network 1.33s; flow+mask computation 0.22
# estimated masks for 1 image(s) in 1.56 sec
# >>>> TOTAL TIME 1.56 sec
# -- normalized foci intensity for ms2 is 0.7108576684087345
# -- tracking cell at timepoint 33.
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# >>>> using CPU
# Running test snippet to check if MKL-DNN working
# see https://pytorch.org/docs/stable/backends.html?highlight=mkl
# ** MKL version working - CPU version is sped up. **
# C:\Users\Shiwei\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:180: UserWarning: D:\Analyzed_CellBio\Stam\Lac_Ms_live\210914_263_pos19\mask_control_1\Pos11_DNA_t33.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# C:\Users\Shiwei\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:180: UserWarning: D:\Analyzed_CellBio\Stam\Lac_Ms_live\210914_263_pos19\mask_control_1\Pos11_Lac_t33.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# processing 1 image(s)
# time spent: running network 1.27s; flow+mask computation 0.22
# estimated masks for 1 image(s) in 1.51 sec
# >>>> TOTAL TIME 1.51 sec
# -- normalized foci intensity for ms2 is 1.0507044262826288
# -- tracking cell at timepoint 34.
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# >>>> using CPU
# Running test snippet to check if MKL-DNN working
# see https://pytorch.org/docs/stable/backends.html?highlight=mkl
# ** MKL version working - CPU version is sped up. **
# C:\Users\Shiwei\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:180: UserWarning: D:\Analyzed_CellBio\Stam\Lac_Ms_live\210914_263_pos19\mask_control_1\Pos11_DNA_t34.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# C:\Users\Shiwei\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:180: UserWarning: D:\Analyzed_CellBio\Stam\Lac_Ms_live\210914_263_pos19\mask_control_1\Pos11_Lac_t34.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# processing 1 image(s)
# time spent: running network 1.32s; flow+mask computation 0.24
# estimated masks for 1 image(s) in 1.58 sec
# >>>> TOTAL TIME 1.58 sec
# -- normalized foci intensity for ms2 is 0.9598318644129282
# -- tracking cell at timepoint 35.
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# >>>> using CPU
# Running test snippet to check if MKL-DNN working
# see https://pytorch.org/docs/stable/backends.html?highlight=mkl
# ** MKL version working - CPU version is sped up. **
# C:\Users\Shiwei\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:180: UserWarning: D:\Analyzed_CellBio\Stam\Lac_Ms_live\210914_263_pos19\mask_control_1\Pos11_DNA_t35.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# C:\Users\Shiwei\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:180: UserWarning: D:\Analyzed_CellBio\Stam\Lac_Ms_live\210914_263_pos19\mask_control_1\Pos11_Lac_t35.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# processing 1 image(s)
# time spent: running network 1.45s; flow+mask computation 0.25
# estimated masks for 1 image(s) in 1.72 sec
# >>>> TOTAL TIME 1.72 sec
# -- normalized foci intensity for ms2 is 0.8454922809720381
# -- tracking cell at timepoint 36.
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# >>>> using CPU
# Running test snippet to check if MKL-DNN working
# see https://pytorch.org/docs/stable/backends.html?highlight=mkl
# ** MKL version working - CPU version is sped up. **
# C:\Users\Shiwei\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:180: UserWarning: D:\Analyzed_CellBio\Stam\Lac_Ms_live\210914_263_pos19\mask_control_1\Pos11_DNA_t36.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# C:\Users\Shiwei\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:180: UserWarning: D:\Analyzed_CellBio\Stam\Lac_Ms_live\210914_263_pos19\mask_control_1\Pos11_Lac_t36.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# processing 1 image(s)
# time spent: running network 1.24s; flow+mask computation 0.21
# estimated masks for 1 image(s) in 1.47 sec
# >>>> TOTAL TIME 1.47 sec
# -- normalized foci intensity for ms2 is 1.3529170623140727
# -- tracking cell at timepoint 37.
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# C:\Users\Shiwei\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:180: UserWarning: D:\Analyzed_CellBio\Stam\Lac_Ms_live\210914_263_pos19\mask_control_1\Pos11_DNA_t37.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# C:\Users\Shiwei\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:180: UserWarning: D:\Analyzed_CellBio\Stam\Lac_Ms_live\210914_263_pos19\mask_control_1\Pos11_Lac_t37.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# >>>> using CPU
# Running test snippet to check if MKL-DNN working
# see https://pytorch.org/docs/stable/backends.html?highlight=mkl
# ** MKL version working - CPU version is sped up. **
# processing 1 image(s)
# time spent: running network 1.31s; flow+mask computation 0.22
# estimated masks for 1 image(s) in 1.55 sec
# >>>> TOTAL TIME 1.55 sec
# -- normalized foci intensity for ms2 is 1.1143852417870859
# -- tracking cell at timepoint 38.
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# >>>> using CPU
# Running test snippet to check if MKL-DNN working
# C:\Users\Shiwei\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:180: UserWarning: D:\Analyzed_CellBio\Stam\Lac_Ms_live\210914_263_pos19\mask_control_1\Pos11_DNA_t38.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# C:\Users\Shiwei\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:180: UserWarning: D:\Analyzed_CellBio\Stam\Lac_Ms_live\210914_263_pos19\mask_control_1\Pos11_Lac_t38.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# see https://pytorch.org/docs/stable/backends.html?highlight=mkl
# ** MKL version working - CPU version is sped up. **
# processing 1 image(s)
# time spent: running network 1.30s; flow+mask computation 0.25
# estimated masks for 1 image(s) in 1.58 sec
# >>>> TOTAL TIME 1.58 sec
# -- normalized foci intensity for ms2 is 0.863579396658419
# -- tracking cell at timepoint 39.
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# C:\Users\Shiwei\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:180: UserWarning: D:\Analyzed_CellBio\Stam\Lac_Ms_live\210914_263_pos19\mask_control_1\Pos11_DNA_t39.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# C:\Users\Shiwei\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:180: UserWarning: D:\Analyzed_CellBio\Stam\Lac_Ms_live\210914_263_pos19\mask_control_1\Pos11_Lac_t39.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# >>>> using CPU
# Running test snippet to check if MKL-DNN working
# see https://pytorch.org/docs/stable/backends.html?highlight=mkl
# ** MKL version working - CPU version is sped up. **
# processing 1 image(s)
# time spent: running network 1.33s; flow+mask computation 0.23
# estimated masks for 1 image(s) in 1.58 sec
# >>>> TOTAL TIME 1.58 sec
# -- normalized foci intensity for ms2 is 1.3450642739075833
# -- tracking cell at timepoint 40.
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# C:\Users\Shiwei\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:180: UserWarning: D:\Analyzed_CellBio\Stam\Lac_Ms_live\210914_263_pos19\mask_control_1\Pos11_DNA_t40.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# C:\Users\Shiwei\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:180: UserWarning: D:\Analyzed_CellBio\Stam\Lac_Ms_live\210914_263_pos19\mask_control_1\Pos11_Lac_t40.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# >>>> using CPU
# Running test snippet to check if MKL-DNN working
# see https://pytorch.org/docs/stable/backends.html?highlight=mkl
# ** MKL version working - CPU version is sped up. **
# processing 1 image(s)
# time spent: running network 1.36s; flow+mask computation 0.20
# estimated masks for 1 image(s) in 1.59 sec
# >>>> TOTAL TIME 1.59 sec
# -- normalized foci intensity for ms2 is 0.9708516808439889
# -- tracking cell at timepoint 41.
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# >>>> using CPU
# Running test snippet to check if MKL-DNN working
# see https://pytorch.org/docs/stable/backends.html?highlight=mkl
# ** MKL version working - CPU version is sped up. **
# C:\Users\Shiwei\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:180: UserWarning: D:\Analyzed_CellBio\Stam\Lac_Ms_live\210914_263_pos19\mask_control_1\Pos11_DNA_t41.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# C:\Users\Shiwei\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:180: UserWarning: D:\Analyzed_CellBio\Stam\Lac_Ms_live\210914_263_pos19\mask_control_1\Pos11_Lac_t41.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# processing 1 image(s)
# time spent: running network 1.37s; flow+mask computation 0.21
# estimated masks for 1 image(s) in 1.60 sec
# >>>> TOTAL TIME 1.60 sec
# -- normalized foci intensity for ms2 is 1.4361414017143725
# -- tracking cell at timepoint 42.
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# C:\Users\Shiwei\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:180: UserWarning: D:\Analyzed_CellBio\Stam\Lac_Ms_live\210914_263_pos19\mask_control_1\Pos11_DNA_t42.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# ...
# >>>> using CPU
# Running test snippet to check if MKL-DNN working
# see https://pytorch.org/docs/stable/backends.html?highlight=mkl
# ** MKL version working - CPU version is sped up. **
# processing 1 image(s)
# time spent: running network 1.56s; flow+mask computation 0.22
# estimated masks for 1 image(s) in 1.81 sec
# >>>> TOTAL TIME 1.81 sec
# -- normalized foci intensity for ms2 is 3.666115331735148
# -- tracking cell at timepoint 77.
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# >>>> using CPU
# Running test snippet to check if MKL-DNN working
# see https://pytorch.org/docs/stable/backends.html?highlight=mkl
# ** MKL version working - CPU version is sped up. **
# C:\Users\Shiwei\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:180: UserWarning: D:\Analyzed_CellBio\Stam\Lac_Ms_live\210914_263_pos19\mask_control_1\Pos11_DNA_t77.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# C:\Users\Shiwei\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:180: UserWarning: D:\Analyzed_CellBio\Stam\Lac_Ms_live\210914_263_pos19\mask_control_1\Pos11_Lac_t77.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# processing 1 image(s)
# time spent: running network 1.55s; flow+mask computation 0.25
# estimated masks for 1 image(s) in 1.82 sec
# >>>> TOTAL TIME 1.82 sec
# -- normalized foci intensity for ms2 is 3.3270118546009964
# -- tracking cell at timepoint 78.
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# >>>> using CPU
# Running test snippet to check if MKL-DNN working
# see https://pytorch.org/docs/stable/backends.html?highlight=mkl
# ** MKL version working - CPU version is sped up. **
# C:\Users\Shiwei\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:180: UserWarning: D:\Analyzed_CellBio\Stam\Lac_Ms_live\210914_263_pos19\mask_control_1\Pos11_DNA_t78.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# C:\Users\Shiwei\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:180: UserWarning: D:\Analyzed_CellBio\Stam\Lac_Ms_live\210914_263_pos19\mask_control_1\Pos11_Lac_t78.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# processing 1 image(s)
# time spent: running network 1.56s; flow+mask computation 0.25
# estimated masks for 1 image(s) in 1.83 sec
# >>>> TOTAL TIME 1.83 sec
# -- normalized foci intensity for ms2 is 2.908282624888326
# -- tracking cell at timepoint 79.
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# >>>> using CPU
# Running test snippet to check if MKL-DNN working
# see https://pytorch.org/docs/stable/backends.html?highlight=mkl
# ** MKL version working - CPU version is sped up. **
# C:\Users\Shiwei\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:180: UserWarning: D:\Analyzed_CellBio\Stam\Lac_Ms_live\210914_263_pos19\mask_control_1\Pos11_DNA_t79.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# C:\Users\Shiwei\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:180: UserWarning: D:\Analyzed_CellBio\Stam\Lac_Ms_live\210914_263_pos19\mask_control_1\Pos11_Lac_t79.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# processing 1 image(s)
# time spent: running network 1.59s; flow+mask computation 0.23
# estimated masks for 1 image(s) in 1.84 sec
# >>>> TOTAL TIME 1.84 sec
# -- normalized foci intensity for ms2 is 4.167736029901266
# -- tracking cell at timepoint 80.
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# C:\Users\Shiwei\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:180: UserWarning: D:\Analyzed_CellBio\Stam\Lac_Ms_live\210914_263_pos19\mask_control_1\Pos11_DNA_t80.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# C:\Users\Shiwei\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:180: UserWarning: D:\Analyzed_CellBio\Stam\Lac_Ms_live\210914_263_pos19\mask_control_1\Pos11_Lac_t80.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# >>>> using CPU
# Running test snippet to check if MKL-DNN working
# see https://pytorch.org/docs/stable/backends.html?highlight=mkl
# ** MKL version working - CPU version is sped up. **
# processing 1 image(s)
# time spent: running network 1.67s; flow+mask computation 0.25
# estimated masks for 1 image(s) in 1.93 sec
# >>>> TOTAL TIME 1.93 sec
# -- normalized foci intensity for ms2 is 3.856713302292326
# -- tracking cell at timepoint 81.
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# C:\Users\Shiwei\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:180: UserWarning: D:\Analyzed_CellBio\Stam\Lac_Ms_live\210914_263_pos19\mask_control_1\Pos11_DNA_t81.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# C:\Users\Shiwei\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:180: UserWarning: D:\Analyzed_CellBio\Stam\Lac_Ms_live\210914_263_pos19\mask_control_1\Pos11_Lac_t81.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# >>>> using CPU
# Running test snippet to check if MKL-DNN working
# see https://pytorch.org/docs/stable/backends.html?highlight=mkl
# ** MKL version working - CPU version is sped up. **
# processing 1 image(s)
# time spent: running network 1.56s; flow+mask computation 0.26
# estimated masks for 1 image(s) in 1.84 sec
# >>>> TOTAL TIME 1.84 sec
# -- normalized foci intensity for ms2 is 4.191559773922244
# -- tracking cell at timepoint 82.
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# C:\Users\Shiwei\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:180: UserWarning: D:\Analyzed_CellBio\Stam\Lac_Ms_live\210914_263_pos19\mask_control_1\Pos11_DNA_t82.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# C:\Users\Shiwei\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:180: UserWarning: D:\Analyzed_CellBio\Stam\Lac_Ms_live\210914_263_pos19\mask_control_1\Pos11_Lac_t82.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# >>>> using CPU
# Running test snippet to check if MKL-DNN working
# see https://pytorch.org/docs/stable/backends.html?highlight=mkl
# ** MKL version working - CPU version is sped up. **
# processing 1 image(s)
# time spent: running network 1.57s; flow+mask computation 0.24
# estimated masks for 1 image(s) in 1.84 sec
# >>>> TOTAL TIME 1.84 sec
# -- normalized foci intensity for ms2 is 3.834874893976865
# -- tracking cell at timepoint 83.
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# C:\Users\Shiwei\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:180: UserWarning: D:\Analyzed_CellBio\Stam\Lac_Ms_live\210914_263_pos19\mask_control_1\Pos11_DNA_t83.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# C:\Users\Shiwei\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:180: UserWarning: D:\Analyzed_CellBio\Stam\Lac_Ms_live\210914_263_pos19\mask_control_1\Pos11_Lac_t83.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# >>>> using CPU
# Running test snippet to check if MKL-DNN working
# see https://pytorch.org/docs/stable/backends.html?highlight=mkl
# ** MKL version working - CPU version is sped up. **
# processing 1 image(s)
# time spent: running network 1.58s; flow+mask computation 0.24
# estimated masks for 1 image(s) in 1.84 sec
# >>>> TOTAL TIME 1.84 sec
# -- normalized foci intensity for ms2 is 4.338801542761839
# -- tracking cell at timepoint 84.
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# >>>> using CPU
# Running test snippet to check if MKL-DNN working
# see https://pytorch.org/docs/stable/backends.html?highlight=mkl
# ** MKL version working - CPU version is sped up. **
# C:\Users\Shiwei\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:180: UserWarning: D:\Analyzed_CellBio\Stam\Lac_Ms_live\210914_263_pos19\mask_control_1\Pos11_DNA_t84.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# C:\Users\Shiwei\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:180: UserWarning: D:\Analyzed_CellBio\Stam\Lac_Ms_live\210914_263_pos19\mask_control_1\Pos11_Lac_t84.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# processing 1 image(s)
# time spent: running network 1.57s; flow+mask computation 0.25
# estimated masks for 1 image(s) in 1.85 sec
# >>>> TOTAL TIME 1.85 sec
# -- normalized foci intensity for ms2 is 3.7522917642535587
# -- tracking cell at timepoint 85.
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# C:\Users\Shiwei\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:180: UserWarning: D:\Analyzed_CellBio\Stam\Lac_Ms_live\210914_263_pos19\mask_control_1\Pos11_DNA_t85.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# C:\Users\Shiwei\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:180: UserWarning: D:\Analyzed_CellBio\Stam\Lac_Ms_live\210914_263_pos19\mask_control_1\Pos11_Lac_t85.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# >>>> using CPU
# Running test snippet to check if MKL-DNN working
# see https://pytorch.org/docs/stable/backends.html?highlight=mkl
# ** MKL version working - CPU version is sped up. **
# processing 1 image(s)
# time spent: running network 1.85s; flow+mask computation 0.28
# estimated masks for 1 image(s) in 2.15 sec
# >>>> TOTAL TIME 2.15 sec
# -- normalized foci intensity for ms2 is 3.579942896577351
# -- tracking cell at timepoint 86.
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# C:\Users\Shiwei\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:180: UserWarning: D:\Analyzed_CellBio\Stam\Lac_Ms_live\210914_263_pos19\mask_control_1\Pos11_DNA_t86.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# C:\Users\Shiwei\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:180: UserWarning: D:\Analyzed_CellBio\Stam\Lac_Ms_live\210914_263_pos19\mask_control_1\Pos11_Lac_t86.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# >>>> using CPU
# Running test snippet to check if MKL-DNN working
# see https://pytorch.org/docs/stable/backends.html?highlight=mkl
# ** MKL version working - CPU version is sped up. **
# processing 1 image(s)
# time spent: running network 1.76s; flow+mask computation 0.25
# estimated masks for 1 image(s) in 2.02 sec
# >>>> TOTAL TIME 2.02 sec
# -- normalized foci intensity for ms2 is 4.297568892610649
# -- tracking cell at timepoint 87.
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# C:\Users\Shiwei\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:180: UserWarning: D:\Analyzed_CellBio\Stam\Lac_Ms_live\210914_263_pos19\mask_control_1\Pos11_DNA_t87.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# C:\Users\Shiwei\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:180: UserWarning: D:\Analyzed_CellBio\Stam\Lac_Ms_live\210914_263_pos19\mask_control_1\Pos11_Lac_t87.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# >>>> using CPU
# Running test snippet to check if MKL-DNN working
# see https://pytorch.org/docs/stable/backends.html?highlight=mkl
# ** MKL version working - CPU version is sped up. **
# processing 1 image(s)
# time spent: running network 1.64s; flow+mask computation 0.25
# estimated masks for 1 image(s) in 1.91 sec
# >>>> TOTAL TIME 1.91 sec
# -- normalized foci intensity for ms2 is 4.728438389016063
# -- tracking cell at timepoint 88.
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# C:\Users\Shiwei\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:180: UserWarning: D:\Analyzed_CellBio\Stam\Lac_Ms_live\210914_263_pos19\mask_control_1\Pos11_DNA_t88.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# C:\Users\Shiwei\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:180: UserWarning: D:\Analyzed_CellBio\Stam\Lac_Ms_live\210914_263_pos19\mask_control_1\Pos11_Lac_t88.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# >>>> using CPU
# Running test snippet to check if MKL-DNN working
# see https://pytorch.org/docs/stable/backends.html?highlight=mkl
# ** MKL version working - CPU version is sped up. **
# processing 1 image(s)
# time spent: running network 1.61s; flow+mask computation 0.24
# estimated masks for 1 image(s) in 1.87 sec
# >>>> TOTAL TIME 1.87 sec
# -- normalized foci intensity for ms2 is 4.87752207122352
# -- tracking cell at timepoint 89.
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# >>>> using CPU
# Running test snippet to check if MKL-DNN working
# see https://pytorch.org/docs/stable/backends.html?highlight=mkl
# ** MKL version working - CPU version is sped up. **
# C:\Users\Shiwei\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:180: UserWarning: D:\Analyzed_CellBio\Stam\Lac_Ms_live\210914_263_pos19\mask_control_1\Pos11_DNA_t89.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# C:\Users\Shiwei\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:180: UserWarning: D:\Analyzed_CellBio\Stam\Lac_Ms_live\210914_263_pos19\mask_control_1\Pos11_Lac_t89.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# processing 1 image(s)
# time spent: running network 1.60s; flow+mask computation 0.23
# estimated masks for 1 image(s) in 1.85 sec
# >>>> TOTAL TIME 1.85 sec
# -- normalized foci intensity for ms2 is 5.038480767181349
# C:\Users\Shiwei\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:180: UserWarning: D:\Analyzed_CellBio\Stam\Lac_Ms_live\210914_263_pos19\mask_control_1\Pos11_DNA_t90.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
# C:\Users\Shiwei\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:180: UserWarning: D:\Analyzed_CellBio\Stam\Lac_Ms_live\210914_263_pos19\mask_control_1\Pos11_Lac_t90.tif is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.

# %%
# %matplotlib notebook

plt.imshow(im_ms, cmap='gray', vmin=100, vmax=150)
# Out:
# <img src="data:image/png;base64,..." width="638.888905813665">

# %%
ms_intensity = dilation(cell_object_info[0]) * im_ms
ms_intensity_filtered = ms_intensity[ms_intensity!=0]
ms_positive_th =np.mean(ms_intensity_filtered) + np.std(ms_intensity_filtered)*3

ms_mask = (im_ms > ms_positive_th)*cell_object_info[0]
ms_mask = dilation(ms_mask)
ms_mask = remove_small_objects(ms_mask, 15)

# %%
# %matplotlib notebook

plt.imshow(ms_mask)

np.sum(ms_mask)
# Out:
# <img src="data:image/png;base64,..." width="638.888905813665">
# 138

# %%
all_measurement_timed
# Out:
# {'1': 0.8271187096477224,
#  '2': 0.882082720947351,
#  '3': 1.547982965380798,
#  '4': 0.6787546028525607,
#  '5': 1.260548481792696,
#  '6': 1.0476028617482258,
#  '7': 1.1792149152896518,
#  '8': 1.2411936243537856,
#  '9': 1.4553126126697804,
#  '10': 0.9250779527228135,
#  '11': 1.3219570367787157,
#  '12': 0.6671297940470802,
#  '13': 0.8335236316546151,
#  '14': 1.0322009316733534,
#  '15': 0.5889254945528934,
#  '16': 0.6193430558351064,
#  '17': 0.9974520961667269,
#  '18': 0.9378283175369081,
#  '19': 1.0241213175111312,
#  '20': 0.6760178741917963,
#  '21': 1.1219924041275662,
#  '22': 1.1931232278302855,
#  '23': 1.2906974067766521,
#  '24': 1.3012703331990023,
#  '25': 1.187176695053942,
#  '26': 0.849564328621526,
#  '27': 1.076283279237172,
#  '28': 1.1445805834332479,
#  '29': 1.099687122159843,
#  '30': 0.5009958929864152,
#  '31': 0.9614136428744001,
#  '32': 0.9421695544671447,
#  '33': 0.7108576684087345,
#  '34': 1.0507044262826288,
#  '35': 0.9598318644129282,
#  '36': 0.8454922809720381,
#  '37': 1.3529170623140727,
#  '38': 1.1143852417870859,
#  '39': 0.863579396658419,
#  '40': 1.3450642739075833,
#  '41': 0.9708516808439889,
#  '42': 1.4361414017143725,
#  '43': 1.344322870611602,
#  '44': 1.2363693097438289,
#  '45': 1.2080234127029288,
#  '46': 1.3897880863879037,
#  '47': 1.0946993768247297,
#  '48': 1.3422998193918907,
#  '49': 1.4014325243420727,
#  '50': 1.4980483763262609,
#  '51': 1.2275978262719256,
#  '52': 1.0197839049646684,
#  '53': 1.4438973448510768,
#  '54': 1.23787832501037,
#  '55': 1.1948864086215432,
#  '56': 1.0854967940152032,
#  '57': 1.2419023631885397,
#  '58': 1.2275091279517893,
#  '59': 'mitosis',
#  '60': 'mitosis',
#  '61': 'mitosis',
#  '62': 'mitosis',
#  '63': 1.6526563342576803,
#  '64': 2.789339352345051,
#  '65': 2.686123202444472,
#  '66': 2.307586920302819,
#  '67': 3.6420142403153766,
#  '68': 4.42847505357154,
#  '69': 4.294460333275009,
#  '70': 3.6545398160238736,
#  '71': 3.5558785467569525,
#  '72': 3.8922037903516697,
#  '73': 2.869751617230035,
#  '74': 3.553707976079667,
#  '75': 3.186992888824591,
#  '76': 3.567745814128124,
#  '77': 3.666115331735148,
#  '78': 3.3270118546009964,
#  '79': 2.908282624888326,
#  '80': 4.167736029901266,
#  '81': 3.856713302292326,
#  '82': 4.191559773922244,
#  '83': 3.834874893976865,
#  '84': 4.338801542761839,
#  '85': 3.7522917642535587,
#  '86': 3.579942896577351,
#  '87': 4.297568892610649,
#  '88': 4.728438389016063,
#  '89': 4.87752207122352,
#  '90': 5.038480767181349}

# %%
# save measurements as simple excel

df = pd.DataFrame(all_measurement_timed,index=[0])

df.to_excel(data_main_folder + os.sep + f'{data_name}_analysis_{cell_name}.xlsx', index=False)
